# %% [markdown]
# <a href="https://colab.research.google.com/github/AndresSamboni/Book_Examples/blob/main/Example_1_Q_Learning_Agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <FONT COLOR='darkgreen'>***EXAMPLE 1 – Q-LEARNING AGENT***<FONT/>
#
# ---
#
# Building the custom environment
#
# ---

# %%
import gym
from gym import spaces
import numpy as np
from random import randint

# CLASS FOR CUSTOM ENVIRONMENT
class VNFEnvironment(gym.Env):
    # CONSTRUCTOR
    def __init__(self, num_CPU=8, num_RAM=12):
        super(VNFEnvironment, self).__init__()
        self.current_step = 0  # INITIATION OF THE FIRST STEP
        self.max_step = 200  # MAXIMUM NUMBER OF STEPS

        # I CALCULATE 10% OF THE PARAMETERS
        self.cpu_10 = (num_CPU * 10) // 100
        self.ram_10 = (num_RAM * 10) // 100
        if (self.cpu_10 == 0):
          self.cpu_10 = 1
        if (self.ram_10 == 0):
          self.ram_10 = 1

        # I SET THE MINIMUM STARTUP VALUES
        self.min_CPU_init = ((num_CPU * 10) // 100) + 1
        self.min_RAM_init = ((num_RAM * 10) // 100) + 1

        # I SET THE MAXIMUM VALUES AND THE MAXIMUM START VALUES
        self.max_CPU = num_CPU
        self.max_RAM = num_RAM
        self.max_CPU_init = ((num_CPU * 80) // 100) + 1
        self.max_RAM_init = ((num_RAM * 80) // 100) + 1

        # I SET THE INITIAL VALUES
        self.num_CPU = randint(self.min_CPU_init, self.max_CPU_init)  # NUMBER OF INITIAL CPU CORE(S)
        self.num_RAM = randint(self.min_RAM_init, self.max_RAM_init)  # AMOUNT OF INITIAL GB OF RAM

        # I IDENTIFY THE SPACE OF STATES
        self.state_size = 7  # ACTIONS: 0. KEEP BOTH. 1. INCREASE BOTH. 2. DECREASE BOTH.
                            # ACTIONS: 3. MAINTAIN RAM AND INCREASE CPU 4. MAINTAIN RAM AND DECREASE CPU.
                            # ACTIONS: 5. MAINTAIN CPU AND INCREASE RAM. 6. MAINTAIN CPU AND DECREASE RAM.
        self.action_space = spaces.Discrete(self.state_size)

        # DEFINE THE OBSERVATION SPACE
        self.observation_space = spaces.Box(
            low=np.array([0, 0]),
            high=np.array([self.max_CPU, self.max_RAM]),
            dtype=np.int32
        )

        # CREATION OF CPU AND RAM USAGE DICTIONARIES
        self.use_CPU = {
            10: (num_CPU * 10) // 100,
            20: (num_CPU * 20) // 100,
            30: (num_CPU * 30) // 100,
            40: (num_CPU * 40) // 100,
            50: (num_CPU * 50) // 100,
            60: (num_CPU * 60) // 100,
            70: (num_CPU * 70) // 100,
            80: (num_CPU * 80) // 100,
            90: (num_CPU * 90) // 100,
            100: num_CPU
        }
        self.use_RAM = {
            10: (num_RAM * 10) // 100,
            20: (num_RAM * 20) // 100,
            30: (num_RAM * 30) // 100,
            40: (num_RAM * 40) // 100,
            50: (num_RAM * 50) // 100,
            60: (num_RAM * 60) // 100,
            70: (num_RAM * 70) // 100,
            80: (num_RAM * 80) // 100,
            90: (num_RAM * 90) // 100,
            100: num_RAM
        }

        # INITIALIZE ACCUMULATED REWARDS
        self.total_reward = 0
        self.reward_CPU = 0
        self.reward_RAM = 0

    # RESET FUNCTION
    def reset(self):
        self.current_step = 0  # INITIATION OF THE FIRST STEP
        self.num_CPU = randint(self.min_CPU_init, self.max_CPU_init)  # NUMBER OF INITIAL CPU CORE(S)
        self.num_RAM = randint(self.min_RAM_init, self.max_RAM_init)  # AMOUNT OF INITIAL GB OF RAM
        # RESET REWARD VALUES
        self.total_reward = 0
        self.reward_CPU = 0
        self.reward_RAM = 0
        return self._get_state()

    def _get_state(self):
        return np.array([self.num_CPU, self.num_RAM])

    # FUNCTION FOR STEP ACTIONS
    def step(self, action):
        self.current_step += 1

        # REACTIONS TO THE AGENT'S ACTIONS
        if action == 0: #0. KEEP BOTH
            pass
        elif action == 1: #1. INCREASE BOTH
            self.num_CPU = min(self.num_CPU + self.cpu_10, self.max_CPU)
            self.num_RAM = min(self.num_RAM + self.ram_10, self.max_RAM)
        elif action == 2: #2. DECREASE BOTH
            self.num_CPU = max(self.num_CPU - self.cpu_10, 0)
            self.num_RAM = max(self.num_RAM - self.ram_10, 0)
        elif action == 3: #3. KEEP RAM AND BOOST CPU
            self.num_CPU = min(self.num_CPU + self.cpu_10, self.max_CPU)
        elif action == 4: #4. KEEP RAM AND DECREASE CPU
            self.num_CPU = max(self.num_CPU - self.cpu_10, 0)
        elif action == 5: #5. MAINTAIN CPU AND INCREASE RAM
            self.num_RAM = min(self.num_RAM + self.ram_10, self.max_RAM)
        elif action == 6: #6. KEEP CPU AND DECREASE RAM
            self.num_RAM = max(self.num_RAM - self.ram_10, 0)

        # REWARD CALCULATION
        reward, cpu_reward, ram_reward = self._calculate_reward()

        # UPDATE ACCUMULATED REWARDS
        self.total_reward += reward
        self.reward_CPU = cpu_reward
        self.reward_RAM = ram_reward

        # CHECK IF I FINISHED THE EPISODE
        done = self._check_done()

        # GET CURRENT STATUS
        state = self._get_state()

        return state, reward, done, {}

    # FUNCTION FOR REWARD CALCULATION
    def _calculate_reward(self):
        cpu_reward = 0
        ram_reward = 0

       # I CALCULATE THE REWARD FOR THE CPU
        if self.num_CPU <= self.use_CPU[10] or self.num_CPU >= self.use_CPU[80]:
            cpu_reward = -50
        elif self.use_CPU[10] < self.num_CPU < self.use_CPU[70]:
            cpu_reward = -1
        elif self.use_CPU[70] < self.num_CPU < self.use_CPU[80]:
            cpu_reward = -1
        elif self.num_CPU == self.use_CPU[70]:
            cpu_reward = 50

        # I CALCULATE THE RECOMPENSATION FOR THE RAM
        if self.num_RAM <= self.use_RAM[10] or self.num_RAM >= self.use_RAM[80]:
            ram_reward = -50
        elif self.use_RAM[10] < self.num_RAM < self.use_RAM[70]:
            ram_reward = -1
        elif self.use_RAM[70] < self.num_RAM < self.use_RAM[80]:
            ram_reward = -1
        elif self.num_RAM == self.use_RAM[70]:
            ram_reward = 50

        total_reward = cpu_reward + ram_reward
        return total_reward, cpu_reward, ram_reward

    # FUNCTION TO CHECK IF THE EPISODE ENDS
    def _check_done(self):
        if self.current_step >= self.max_step:
            return True
        if self.reward_CPU <= -50:
            return True
        if self.reward_RAM <= -50:
            return True
        if self.reward_CPU <= -50 and self.reward_RAM <= -50:
            return True
        if self.reward_CPU == 50 and self.reward_RAM == 50:
            return True
        return False

# %% [markdown]
# ---
#
# Reinforcement learning **( RL )** agent training.
#
# ---

# %%
import random
from collections import defaultdict
import pandas as pd  # Import pandas

# Environment initialization
env = VNFEnvironment()

# Q-Learning parameters
alpha = 0.0001  # Learning rate
gamma = 0.95  # Discount factor
epsilon = 1.0  # Maximum scan-exploit parameter
epsilon_min = 0.001 # Minimum scan-exploit parameter
epsilon_decay = 0.9995 # Explore-exploit decay parameter
num_episodes = 15000 # Episodes
max_steps = env.max_step

# Q table initialization
Q = defaultdict(lambda: np.zeros(env.action_space.n))

# Function to choose an action using the epsilon-greedy policy
def epsilon_greedy_policy(state, epsilon):
    if random.random() < epsilon:
        return env.action_space.sample()  # Exploration
    else:
        return np.argmax(Q[state])  # Exploitation

# List to follow the rewards accumulated per episode
rewards_per_episode = []
cpu_usage_final_per_episode = []

# Agent training
for episode in range(num_episodes):
    state = tuple(env.reset())
    total_reward = 0

    for t in range(max_steps):
        action = epsilon_greedy_policy(state, epsilon)
        next_state, reward, done, _ = env.step(action)
        next_state = tuple(next_state)

        # Q table update
        best_next_action = np.argmax(Q[next_state])
        td_target = reward + gamma * Q[next_state][best_next_action]
        td_delta = td_target - Q[state][action]
        Q[state][action] += alpha * td_delta

        total_reward += reward
        state = next_state

        if done:
            break

    # Epsilon decay
    if epsilon > epsilon_min:
        epsilon *= epsilon_decay

    rewards_per_episode.append(total_reward)
    cpu_usage_final_per_episode.append(env.num_CPU)  # Record the number of cores used at the end of the episode

    if episode % 1 == 0:
        print(f"\nEpisode {episode}/{num_episodes}: Total reward = {total_reward}\nEpisode {episode}/{num_episodes}: Epsilon = {epsilon:.4f}")
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Episode 13333/15000: Total reward = 100
# Episode 13333/15000: Epsilon = 0.0013
#
# Episode 13334/15000: Total reward = -51
# Episode 13334/15000: Epsilon = 0.0013
#
# Episode 13335/15000: Total reward = -51
# Episode 13335/15000: Epsilon = 0.0013
#
# Episode 13336/15000: Total reward = -51
# Episode 13336/15000: Epsilon = 0.0013
#
# Episode 13337/15000: Total reward = -51
# Episode 13337/15000: Epsilon = 0.0013
#
# Episode 13338/15000: Total reward = 100
# Episode 13338/15000: Epsilon = 0.0013
#
# Episode 13339/15000: Total reward = 149
# Episode 13339/15000: Epsilon = 0.0013
#
# Episode 13340/15000: Total reward = 149
# Episode 13340/15000: Epsilon = 0.0013
#
# Episode 13341/15000: Total reward = 198
# Episode 13341/15000: Epsilon = 0.0013
#
# Episode 13342/15000: Total reward = 0
# Episode 13342/15000: Epsilon = 0.0013
#
# Episode 13343/15000: Total reward = -51
# Episode 13343/15000: Epsilon = 0.0013
#
# Episode 13344/15000: Total reward = 4943
# Episode 13344/15000: Epsilon = 0.0013
#
# Episode 13345/15000: Total reward = 9800
# Episode 13345/15000: Epsilon = 0.0013
#
# Episode 13346/15000: Total reward = 9749
# Episode 13346/15000: Epsilon = 0.0013
#
# Episode 13347/15000: Total reward = 9392
# Episode 13347/15000: Epsilon = 0.0013
#
# Episode 13348/15000: Total reward = 9749
# Episode 13348/15000: Epsilon = 0.0013
#
# Episode 13349/15000: Total reward = 9749
# Episode 13349/15000: Epsilon = 0.0013
#
# Episode 13350/15000: Total reward = 100
# Episode 13350/15000: Epsilon = 0.0013
#
# Episode 13351/15000: Total reward = 9698
# Episode 13351/15000: Epsilon = 0.0013
#
# Episode 13352/15000: Total reward = -51
# Episode 13352/15000: Epsilon = 0.0013
#
# Episode 13353/15000: Total reward = 9749
# Episode 13353/15000: Epsilon = 0.0013
#
# Episode 13354/15000: Total reward = 9443
# Episode 13354/15000: Epsilon = 0.0013
#
# Episode 13355/15000: Total reward = 7203
# Episode 13355/15000: Epsilon = 0.0013
#
# Episode 13356/15000: Total reward = -51
# Episode 13356/15000: Epsilon = 0.0013
#
# Episode 13357/15000: Total reward = 149
# Episode 13357/15000: Epsilon = 0.0013
#
# Episode 13358/15000: Total reward = -51
# Episode 13358/15000: Epsilon = 0.0013
#
# Episode 13359/15000: Total reward = 100
# Episode 13359/15000: Epsilon = 0.0013
#
# Episode 13360/15000: Total reward = -51
# Episode 13360/15000: Epsilon = 0.0013
#
# Episode 13361/15000: Total reward = 9800
# Episode 13361/15000: Epsilon = 0.0013
#
# Episode 13362/15000: Total reward = 9494
# Episode 13362/15000: Epsilon = 0.0013
#
# Episode 13363/15000: Total reward = 0
# Episode 13363/15000: Epsilon = 0.0013
#
# Episode 13364/15000: Total reward = -51
# Episode 13364/15000: Epsilon = 0.0013
#
# Episode 13365/15000: Total reward = -51
# Episode 13365/15000: Epsilon = 0.0012
#
# Episode 13366/15000: Total reward = 6711
# Episode 13366/15000: Epsilon = 0.0012
#
# Episode 13367/15000: Total reward = 9800
# Episode 13367/15000: Epsilon = 0.0012
#
# Episode 13368/15000: Total reward = 9800
# Episode 13368/15000: Epsilon = 0.0012
#
# Episode 13369/15000: Total reward = 9800
# Episode 13369/15000: Epsilon = 0.0012
#
# Episode 13370/15000: Total reward = 149
# Episode 13370/15000: Epsilon = 0.0012
#
# Episode 13371/15000: Total reward = 0
# Episode 13371/15000: Epsilon = 0.0012
#
# Episode 13372/15000: Total reward = 9800
# Episode 13372/15000: Epsilon = 0.0012
#
# Episode 13373/15000: Total reward = 149
# Episode 13373/15000: Epsilon = 0.0012
#
# Episode 13374/15000: Total reward = 9749
# Episode 13374/15000: Epsilon = 0.0012
#
# Episode 13375/15000: Total reward = 7781
# Episode 13375/15000: Epsilon = 0.0012
#
# Episode 13376/15000: Total reward = 9494
# Episode 13376/15000: Epsilon = 0.0012
#
# Episode 13377/15000: Total reward = 9800
# Episode 13377/15000: Epsilon = 0.0012
#
# Episode 13378/15000: Total reward = -51
# Episode 13378/15000: Epsilon = 0.0012
#
# Episode 13379/15000: Total reward = 9749
# Episode 13379/15000: Epsilon = 0.0012
#
# Episode 13380/15000: Total reward = 9800
# Episode 13380/15000: Epsilon = 0.0012
#
# Episode 13381/15000: Total reward = 9800
# Episode 13381/15000: Epsilon = 0.0012
#
# Episode 13382/15000: Total reward = 9800
# Episode 13382/15000: Epsilon = 0.0012
#
# Episode 13383/15000: Total reward = 9698
# Episode 13383/15000: Epsilon = 0.0012
#
# Episode 13384/15000: Total reward = 9800
# Episode 13384/15000: Epsilon = 0.0012
#
# Episode 13385/15000: Total reward = 9800
# Episode 13385/15000: Epsilon = 0.0012
#
# Episode 13386/15000: Total reward = 100
# Episode 13386/15000: Epsilon = 0.0012
#
# Episode 13387/15000: Total reward = 9800
# Episode 13387/15000: Epsilon = 0.0012
#
# Episode 13388/15000: Total reward = 9800
# Episode 13388/15000: Epsilon = 0.0012
#
# Episode 13389/15000: Total reward = 100
# Episode 13389/15000: Epsilon = 0.0012
#
# Episode 13390/15000: Total reward = 9749
# Episode 13390/15000: Epsilon = 0.0012
#
# Episode 13391/15000: Total reward = 149
# Episode 13391/15000: Epsilon = 0.0012
#
# Episode 13392/15000: Total reward = -51
# Episode 13392/15000: Epsilon = 0.0012
#
# Episode 13393/15000: Total reward = 9239
# Episode 13393/15000: Epsilon = 0.0012
#
# Episode 13394/15000: Total reward = 9749
# Episode 13394/15000: Epsilon = 0.0012
#
# Episode 13395/15000: Total reward = 9800
# Episode 13395/15000: Epsilon = 0.0012
#
# Episode 13396/15000: Total reward = -51
# Episode 13396/15000: Epsilon = 0.0012
#
# Episode 13397/15000: Total reward = 9749
# Episode 13397/15000: Epsilon = 0.0012
#
# Episode 13398/15000: Total reward = 9647
# Episode 13398/15000: Epsilon = 0.0012
#
# Episode 13399/15000: Total reward = -51
# Episode 13399/15000: Epsilon = 0.0012
#
# Episode 13400/15000: Total reward = -51
# Episode 13400/15000: Epsilon = 0.0012
#
# Episode 13401/15000: Total reward = 9290
# Episode 13401/15000: Epsilon = 0.0012
#
# Episode 13402/15000: Total reward = 9800
# Episode 13402/15000: Epsilon = 0.0012
#
# Episode 13403/15000: Total reward = -100
# Episode 13403/15000: Epsilon = 0.0012
#
# Episode 13404/15000: Total reward = 149
# Episode 13404/15000: Epsilon = 0.0012
#
# Episode 13405/15000: Total reward = -51
# Episode 13405/15000: Epsilon = 0.0012
#
# Episode 13406/15000: Total reward = 100
# Episode 13406/15000: Epsilon = 0.0012
#
# Episode 13407/15000: Total reward = 9749
# Episode 13407/15000: Epsilon = 0.0012
#
# Episode 13408/15000: Total reward = 1617
# Episode 13408/15000: Epsilon = 0.0012
#
# Episode 13409/15000: Total reward = 0
# Episode 13409/15000: Epsilon = 0.0012
#
# Episode 13410/15000: Total reward = 9494
# Episode 13410/15000: Epsilon = 0.0012
#
# Episode 13411/15000: Total reward = 9698
# Episode 13411/15000: Epsilon = 0.0012
#
# Episode 13412/15000: Total reward = 9443
# Episode 13412/15000: Epsilon = 0.0012
#
# Episode 13413/15000: Total reward = 149
# Episode 13413/15000: Epsilon = 0.0012
#
# Episode 13414/15000: Total reward = 9800
# Episode 13414/15000: Epsilon = 0.0012
#
# Episode 13415/15000: Total reward = 9749
# Episode 13415/15000: Epsilon = 0.0012
#
# Episode 13416/15000: Total reward = -51
# Episode 13416/15000: Epsilon = 0.0012
#
# Episode 13417/15000: Total reward = 4359
# Episode 13417/15000: Epsilon = 0.0012
#
# Episode 13418/15000: Total reward = 9800
# Episode 13418/15000: Epsilon = 0.0012
#
# Episode 13419/15000: Total reward = 9749
# Episode 13419/15000: Epsilon = 0.0012
#
# Episode 13420/15000: Total reward = -51
# Episode 13420/15000: Epsilon = 0.0012
#
# Episode 13421/15000: Total reward = 198
# Episode 13421/15000: Epsilon = 0.0012
#
# Episode 13422/15000: Total reward = 0
# Episode 13422/15000: Epsilon = 0.0012
#
# Episode 13423/15000: Total reward = -51
# Episode 13423/15000: Epsilon = 0.0012
#
# Episode 13424/15000: Total reward = 9800
# Episode 13424/15000: Epsilon = 0.0012
#
# Episode 13425/15000: Total reward = -100
# Episode 13425/15000: Epsilon = 0.0012
#
# Episode 13426/15000: Total reward = 9800
# Episode 13426/15000: Epsilon = 0.0012
#
# Episode 13427/15000: Total reward = -100
# Episode 13427/15000: Epsilon = 0.0012
#
# Episode 13428/15000: Total reward = 100
# Episode 13428/15000: Epsilon = 0.0012
#
# Episode 13429/15000: Total reward = 0
# Episode 13429/15000: Epsilon = 0.0012
#
# Episode 13430/15000: Total reward = 9800
# Episode 13430/15000: Epsilon = 0.0012
#
# Episode 13431/15000: Total reward = 100
# Episode 13431/15000: Epsilon = 0.0012
#
# Episode 13432/15000: Total reward = 4214
# Episode 13432/15000: Epsilon = 0.0012
#
# Episode 13433/15000: Total reward = 9749
# Episode 13433/15000: Epsilon = 0.0012
#
# Episode 13434/15000: Total reward = 6466
# Episode 13434/15000: Epsilon = 0.0012
#
# Episode 13435/15000: Total reward = 9800
# Episode 13435/15000: Epsilon = 0.0012
#
# Episode 13436/15000: Total reward = 9800
# Episode 13436/15000: Epsilon = 0.0012
#
# Episode 13437/15000: Total reward = 0
# Episode 13437/15000: Epsilon = 0.0012
#
# Episode 13438/15000: Total reward = 9749
# Episode 13438/15000: Epsilon = 0.0012
#
# Episode 13439/15000: Total reward = 9800
# Episode 13439/15000: Epsilon = 0.0012
#
# Episode 13440/15000: Total reward = -51
# Episode 13440/15000: Epsilon = 0.0012
#
# Episode 13441/15000: Total reward = -51
# Episode 13441/15000: Epsilon = 0.0012
#
# Episode 13442/15000: Total reward = 9800
# Episode 13442/15000: Epsilon = 0.0012
#
# Episode 13443/15000: Total reward = 6564
# Episode 13443/15000: Epsilon = 0.0012
#
# Episode 13444/15000: Total reward = 9800
# Episode 13444/15000: Epsilon = 0.0012
#
# Episode 13445/15000: Total reward = 0
# Episode 13445/15000: Epsilon = 0.0012
#
# Episode 13446/15000: Total reward = 9800
# Episode 13446/15000: Epsilon = 0.0012
#
# Episode 13447/15000: Total reward = 9800
# Episode 13447/15000: Epsilon = 0.0012
#
# Episode 13448/15000: Total reward = 9749
# Episode 13448/15000: Epsilon = 0.0012
#
# Episode 13449/15000: Total reward = 9749
# Episode 13449/15000: Epsilon = 0.0012
#
# Episode 13450/15000: Total reward = 9443
# Episode 13450/15000: Epsilon = 0.0012
#
# Episode 13451/15000: Total reward = 149
# Episode 13451/15000: Epsilon = 0.0012
#
# Episode 13452/15000: Total reward = 100
# Episode 13452/15000: Epsilon = 0.0012
#
# Episode 13453/15000: Total reward = -51
# Episode 13453/15000: Epsilon = 0.0012
#
# Episode 13454/15000: Total reward = -51
# Episode 13454/15000: Epsilon = 0.0012
#
# Episode 13455/15000: Total reward = 0
# Episode 13455/15000: Epsilon = 0.0012
#
# Episode 13456/15000: Total reward = 0
# Episode 13456/15000: Epsilon = 0.0012
#
# Episode 13457/15000: Total reward = 149
# Episode 13457/15000: Epsilon = 0.0012
#
# Episode 13458/15000: Total reward = 9698
# Episode 13458/15000: Epsilon = 0.0012
#
# Episode 13459/15000: Total reward = 149
# Episode 13459/15000: Epsilon = 0.0012
#
# Episode 13460/15000: Total reward = 149
# Episode 13460/15000: Epsilon = 0.0012
#
# Episode 13461/15000: Total reward = 0
# Episode 13461/15000: Epsilon = 0.0012
#
# Episode 13462/15000: Total reward = 9749
# Episode 13462/15000: Epsilon = 0.0012
#
# Episode 13463/15000: Total reward = 9800
# Episode 13463/15000: Epsilon = 0.0012
#
# Episode 13464/15000: Total reward = -51
# Episode 13464/15000: Epsilon = 0.0012
#
# Episode 13465/15000: Total reward = -100
# Episode 13465/15000: Epsilon = 0.0012
#
# Episode 13466/15000: Total reward = 100
# Episode 13466/15000: Epsilon = 0.0012
#
# Episode 13467/15000: Total reward = 0
# Episode 13467/15000: Epsilon = 0.0012
#
# Episode 13468/15000: Total reward = 100
# Episode 13468/15000: Epsilon = 0.0012
#
# Episode 13469/15000: Total reward = 9392
# Episode 13469/15000: Epsilon = 0.0012
#
# Episode 13470/15000: Total reward = 9800
# Episode 13470/15000: Epsilon = 0.0012
#
# Episode 13471/15000: Total reward = 9800
# Episode 13471/15000: Epsilon = 0.0012
#
# Episode 13472/15000: Total reward = 7150
# Episode 13472/15000: Epsilon = 0.0012
#
# Episode 13473/15000: Total reward = 100
# Episode 13473/15000: Epsilon = 0.0012
#
# Episode 13474/15000: Total reward = 9596
# Episode 13474/15000: Epsilon = 0.0012
#
# Episode 13475/15000: Total reward = 0
# Episode 13475/15000: Epsilon = 0.0012
#
# Episode 13476/15000: Total reward = -100
# Episode 13476/15000: Epsilon = 0.0012
#
# Episode 13477/15000: Total reward = 9800
# Episode 13477/15000: Epsilon = 0.0012
#
# Episode 13478/15000: Total reward = 9749
# Episode 13478/15000: Epsilon = 0.0012
#
# Episode 13479/15000: Total reward = 9800
# Episode 13479/15000: Epsilon = 0.0012
#
# Episode 13480/15000: Total reward = 9698
# Episode 13480/15000: Epsilon = 0.0012
#
# Episode 13481/15000: Total reward = 0
# Episode 13481/15000: Epsilon = 0.0012
#
# Episode 13482/15000: Total reward = 9749
# Episode 13482/15000: Epsilon = 0.0012
#
# Episode 13483/15000: Total reward = 9800
# Episode 13483/15000: Epsilon = 0.0012
#
# Episode 13484/15000: Total reward = 9800
# Episode 13484/15000: Epsilon = 0.0012
#
# Episode 13485/15000: Total reward = 149
# Episode 13485/15000: Epsilon = 0.0012
#
# Episode 13486/15000: Total reward = -51
# Episode 13486/15000: Epsilon = 0.0012
#
# Episode 13487/15000: Total reward = 149
# Episode 13487/15000: Epsilon = 0.0012
#
# Episode 13488/15000: Total reward = 9800
# Episode 13488/15000: Epsilon = 0.0012
#
# Episode 13489/15000: Total reward = 0
# Episode 13489/15000: Epsilon = 0.0012
#
# Episode 13490/15000: Total reward = 9647
# Episode 13490/15000: Epsilon = 0.0012
#
# Episode 13491/15000: Total reward = 100
# Episode 13491/15000: Epsilon = 0.0012
#
# Episode 13492/15000: Total reward = -51
# Episode 13492/15000: Epsilon = 0.0012
#
# Episode 13493/15000: Total reward = 9800
# Episode 13493/15000: Epsilon = 0.0012
#
# Episode 13494/15000: Total reward = 100
# Episode 13494/15000: Epsilon = 0.0012
#
# Episode 13495/15000: Total reward = 9698
# Episode 13495/15000: Epsilon = 0.0012
#
# Episode 13496/15000: Total reward = 9800
# Episode 13496/15000: Epsilon = 0.0012
#
# Episode 13497/15000: Total reward = 9800
# Episode 13497/15000: Epsilon = 0.0012
#
# Episode 13498/15000: Total reward = 8984
# Episode 13498/15000: Epsilon = 0.0012
#
# Episode 13499/15000: Total reward = 0
# Episode 13499/15000: Epsilon = 0.0012
#
# Episode 13500/15000: Total reward = 9647
# Episode 13500/15000: Epsilon = 0.0012
#
# Episode 13501/15000: Total reward = -51
# Episode 13501/15000: Epsilon = 0.0012
#
# Episode 13502/15000: Total reward = 9800
# Episode 13502/15000: Epsilon = 0.0012
#
# Episode 13503/15000: Total reward = 149
# Episode 13503/15000: Epsilon = 0.0012
#
# Episode 13504/15000: Total reward = 9698
# Episode 13504/15000: Epsilon = 0.0012
#
# Episode 13505/15000: Total reward = 149
# Episode 13505/15000: Epsilon = 0.0012
#
# Episode 13506/15000: Total reward = 9749
# Episode 13506/15000: Epsilon = 0.0012
#
# Episode 13507/15000: Total reward = 0
# Episode 13507/15000: Epsilon = 0.0012
#
# Episode 13508/15000: Total reward = 2936
# Episode 13508/15000: Epsilon = 0.0012
#
# Episode 13509/15000: Total reward = 9800
# Episode 13509/15000: Epsilon = 0.0012
#
# Episode 13510/15000: Total reward = -51
# Episode 13510/15000: Epsilon = 0.0012
#
# Episode 13511/15000: Total reward = 9800
# Episode 13511/15000: Epsilon = 0.0012
#
# Episode 13512/15000: Total reward = 100
# Episode 13512/15000: Epsilon = 0.0012
#
# Episode 13513/15000: Total reward = 9698
# Episode 13513/15000: Epsilon = 0.0012
#
# Episode 13514/15000: Total reward = 9647
# Episode 13514/15000: Epsilon = 0.0012
#
# Episode 13515/15000: Total reward = -51
# Episode 13515/15000: Epsilon = 0.0012
#
# Episode 13516/15000: Total reward = 4310
# Episode 13516/15000: Epsilon = 0.0012
#
# Episode 13517/15000: Total reward = 9494
# Episode 13517/15000: Epsilon = 0.0012
#
# Episode 13518/15000: Total reward = 9800
# Episode 13518/15000: Epsilon = 0.0012
#
# Episode 13519/15000: Total reward = -51
# Episode 13519/15000: Epsilon = 0.0012
#
# Episode 13520/15000: Total reward = 5682
# Episode 13520/15000: Epsilon = 0.0012
#
# Episode 13521/15000: Total reward = -51
# Episode 13521/15000: Epsilon = 0.0012
#
# Episode 13522/15000: Total reward = 9800
# Episode 13522/15000: Epsilon = 0.0012
#
# Episode 13523/15000: Total reward = 9749
# Episode 13523/15000: Epsilon = 0.0012
#
# Episode 13524/15000: Total reward = 9800
# Episode 13524/15000: Epsilon = 0.0012
#
# Episode 13525/15000: Total reward = 9341
# Episode 13525/15000: Epsilon = 0.0012
#
# Episode 13526/15000: Total reward = -51
# Episode 13526/15000: Epsilon = 0.0012
#
# Episode 13527/15000: Total reward = -51
# Episode 13527/15000: Epsilon = 0.0012
#
# Episode 13528/15000: Total reward = 149
# Episode 13528/15000: Epsilon = 0.0012
#
# Episode 13529/15000: Total reward = 149
# Episode 13529/15000: Epsilon = 0.0012
#
# Episode 13530/15000: Total reward = 9800
# Episode 13530/15000: Epsilon = 0.0012
#
# Episode 13531/15000: Total reward = 149
# Episode 13531/15000: Epsilon = 0.0012
#
# Episode 13532/15000: Total reward = -51
# Episode 13532/15000: Epsilon = 0.0011
#
# Episode 13533/15000: Total reward = -100
# Episode 13533/15000: Epsilon = 0.0011
#
# Episode 13534/15000: Total reward = 9290
# Episode 13534/15000: Epsilon = 0.0011
#
# Episode 13535/15000: Total reward = -100
# Episode 13535/15000: Epsilon = 0.0011
#
# Episode 13536/15000: Total reward = 0
# Episode 13536/15000: Epsilon = 0.0011
#
# Episode 13537/15000: Total reward = 9800
# Episode 13537/15000: Epsilon = 0.0011
#
# Episode 13538/15000: Total reward = -100
# Episode 13538/15000: Epsilon = 0.0011
#
# Episode 13539/15000: Total reward = 0
# Episode 13539/15000: Epsilon = 0.0011
#
# Episode 13540/15000: Total reward = 9698
# Episode 13540/15000: Epsilon = 0.0011
#
# Episode 13541/15000: Total reward = 0
# Episode 13541/15000: Epsilon = 0.0011
#
# Episode 13542/15000: Total reward = 9749
# Episode 13542/15000: Epsilon = 0.0011
#
# Episode 13543/15000: Total reward = -51
# Episode 13543/15000: Epsilon = 0.0011
#
# Episode 13544/15000: Total reward = 198
# Episode 13544/15000: Epsilon = 0.0011
#
# Episode 13545/15000: Total reward = -51
# Episode 13545/15000: Epsilon = 0.0011
#
# Episode 13546/15000: Total reward = 9800
# Episode 13546/15000: Epsilon = 0.0011
#
# Episode 13547/15000: Total reward = 9749
# Episode 13547/15000: Epsilon = 0.0011
#
# Episode 13548/15000: Total reward = 9647
# Episode 13548/15000: Epsilon = 0.0011
#
# Episode 13549/15000: Total reward = 0
# Episode 13549/15000: Epsilon = 0.0011
#
# Episode 13550/15000: Total reward = 149
# Episode 13550/15000: Epsilon = 0.0011
#
# Episode 13551/15000: Total reward = 9800
# Episode 13551/15000: Epsilon = 0.0011
#
# Episode 13552/15000: Total reward = 9800
# Episode 13552/15000: Epsilon = 0.0011
#
# Episode 13553/15000: Total reward = 9800
# Episode 13553/15000: Epsilon = 0.0011
#
# Episode 13554/15000: Total reward = 9698
# Episode 13554/15000: Epsilon = 0.0011
#
# Episode 13555/15000: Total reward = 0
# Episode 13555/15000: Epsilon = 0.0011
#
# Episode 13556/15000: Total reward = -51
# Episode 13556/15000: Epsilon = 0.0011
#
# Episode 13557/15000: Total reward = 9602
# Episode 13557/15000: Epsilon = 0.0011
#
# Episode 13558/15000: Total reward = 9800
# Episode 13558/15000: Epsilon = 0.0011
#
# Episode 13559/15000: Total reward = 9239
# Episode 13559/15000: Epsilon = 0.0011
#
# Episode 13560/15000: Total reward = 9800
# Episode 13560/15000: Epsilon = 0.0011
#
# Episode 13561/15000: Total reward = 3181
# Episode 13561/15000: Epsilon = 0.0011
#
# Episode 13562/15000: Total reward = 9749
# Episode 13562/15000: Epsilon = 0.0011
#
# Episode 13563/15000: Total reward = 198
# Episode 13563/15000: Epsilon = 0.0011
#
# Episode 13564/15000: Total reward = 9749
# Episode 13564/15000: Epsilon = 0.0011
#
# Episode 13565/15000: Total reward = 100
# Episode 13565/15000: Epsilon = 0.0011
#
# Episode 13566/15000: Total reward = 8661
# Episode 13566/15000: Epsilon = 0.0011
#
# Episode 13567/15000: Total reward = 9800
# Episode 13567/15000: Epsilon = 0.0011
#
# Episode 13568/15000: Total reward = -100
# Episode 13568/15000: Epsilon = 0.0011
#
# Episode 13569/15000: Total reward = 9800
# Episode 13569/15000: Epsilon = 0.0011
#
# Episode 13570/15000: Total reward = 9341
# Episode 13570/15000: Epsilon = 0.0011
#
# Episode 13571/15000: Total reward = 149
# Episode 13571/15000: Epsilon = 0.0011
#
# Episode 13572/15000: Total reward = 9800
# Episode 13572/15000: Epsilon = 0.0011
#
# Episode 13573/15000: Total reward = 149
# Episode 13573/15000: Epsilon = 0.0011
#
# Episode 13574/15000: Total reward = -51
# Episode 13574/15000: Epsilon = 0.0011
#
# Episode 13575/15000: Total reward = 9800
# Episode 13575/15000: Epsilon = 0.0011
#
# Episode 13576/15000: Total reward = 9800
# Episode 13576/15000: Epsilon = 0.0011
#
# Episode 13577/15000: Total reward = 9800
# Episode 13577/15000: Epsilon = 0.0011
#
# Episode 13578/15000: Total reward = 100
# Episode 13578/15000: Epsilon = 0.0011
#
# Episode 13579/15000: Total reward = 9800
# Episode 13579/15000: Epsilon = 0.0011
#
# Episode 13580/15000: Total reward = 9800
# Episode 13580/15000: Epsilon = 0.0011
#
# Episode 13581/15000: Total reward = 0
# Episode 13581/15000: Epsilon = 0.0011
#
# Episode 13582/15000: Total reward = 9749
# Episode 13582/15000: Epsilon = 0.0011
#
# Episode 13583/15000: Total reward = 9647
# Episode 13583/15000: Epsilon = 0.0011
#
# Episode 13584/15000: Total reward = -51
# Episode 13584/15000: Epsilon = 0.0011
#
# Episode 13585/15000: Total reward = 9800
# Episode 13585/15000: Epsilon = 0.0011
#
# Episode 13586/15000: Total reward = 9749
# Episode 13586/15000: Epsilon = 0.0011
#
# Episode 13587/15000: Total reward = 9800
# Episode 13587/15000: Epsilon = 0.0011
#
# Episode 13588/15000: Total reward = 9800
# Episode 13588/15000: Epsilon = 0.0011
#
# Episode 13589/15000: Total reward = 149
# Episode 13589/15000: Epsilon = 0.0011
#
# Episode 13590/15000: Total reward = 9800
# Episode 13590/15000: Epsilon = 0.0011
#
# Episode 13591/15000: Total reward = 9800
# Episode 13591/15000: Epsilon = 0.0011
#
# Episode 13592/15000: Total reward = 9800
# Episode 13592/15000: Epsilon = 0.0011
#
# Episode 13593/15000: Total reward = 9800
# Episode 13593/15000: Epsilon = 0.0011
#
# Episode 13594/15000: Total reward = 9800
# Episode 13594/15000: Epsilon = 0.0011
#
# Episode 13595/15000: Total reward = -51
# Episode 13595/15000: Epsilon = 0.0011
#
# Episode 13596/15000: Total reward = 9800
# Episode 13596/15000: Epsilon = 0.0011
#
# Episode 13597/15000: Total reward = -100
# Episode 13597/15000: Epsilon = 0.0011
#
# Episode 13598/15000: Total reward = 100
# Episode 13598/15000: Epsilon = 0.0011
#
# Episode 13599/15000: Total reward = 9698
# Episode 13599/15000: Epsilon = 0.0011
#
# Episode 13600/15000: Total reward = 9749
# Episode 13600/15000: Epsilon = 0.0011
#
# Episode 13601/15000: Total reward = 8729
# Episode 13601/15000: Epsilon = 0.0011
#
# Episode 13602/15000: Total reward = 100
# Episode 13602/15000: Epsilon = 0.0011
#
# Episode 13603/15000: Total reward = 149
# Episode 13603/15000: Epsilon = 0.0011
#
# Episode 13604/15000: Total reward = 9698
# Episode 13604/15000: Epsilon = 0.0011
#
# Episode 13605/15000: Total reward = 149
# Episode 13605/15000: Epsilon = 0.0011
#
# Episode 13606/15000: Total reward = 9800
# Episode 13606/15000: Epsilon = 0.0011
#
# Episode 13607/15000: Total reward = 100
# Episode 13607/15000: Epsilon = 0.0011
#
# Episode 13608/15000: Total reward = 9749
# Episode 13608/15000: Epsilon = 0.0011
#
# Episode 13609/15000: Total reward = -100
# Episode 13609/15000: Epsilon = 0.0011
#
# Episode 13610/15000: Total reward = 9800
# Episode 13610/15000: Epsilon = 0.0011
#
# Episode 13611/15000: Total reward = 9800
# Episode 13611/15000: Epsilon = 0.0011
#
# Episode 13612/15000: Total reward = -100
# Episode 13612/15000: Epsilon = 0.0011
#
# Episode 13613/15000: Total reward = 149
# Episode 13613/15000: Epsilon = 0.0011
#
# Episode 13614/15000: Total reward = -51
# Episode 13614/15000: Epsilon = 0.0011
#
# Episode 13615/15000: Total reward = 9596
# Episode 13615/15000: Epsilon = 0.0011
#
# Episode 13616/15000: Total reward = 0
# Episode 13616/15000: Epsilon = 0.0011
#
# Episode 13617/15000: Total reward = 149
# Episode 13617/15000: Epsilon = 0.0011
#
# Episode 13618/15000: Total reward = -51
# Episode 13618/15000: Epsilon = 0.0011
#
# Episode 13619/15000: Total reward = 0
# Episode 13619/15000: Epsilon = 0.0011
#
# Episode 13620/15000: Total reward = -51
# Episode 13620/15000: Epsilon = 0.0011
#
# Episode 13621/15000: Total reward = 9800
# Episode 13621/15000: Epsilon = 0.0011
#
# Episode 13622/15000: Total reward = 9749
# Episode 13622/15000: Epsilon = 0.0011
#
# Episode 13623/15000: Total reward = -51
# Episode 13623/15000: Epsilon = 0.0011
#
# Episode 13624/15000: Total reward = -51
# Episode 13624/15000: Epsilon = 0.0011
#
# Episode 13625/15000: Total reward = 9800
# Episode 13625/15000: Epsilon = 0.0011
#
# Episode 13626/15000: Total reward = 9749
# Episode 13626/15000: Epsilon = 0.0011
#
# Episode 13627/15000: Total reward = -100
# Episode 13627/15000: Epsilon = 0.0011
#
# Episode 13628/15000: Total reward = 3375
# Episode 13628/15000: Epsilon = 0.0011
#
# Episode 13629/15000: Total reward = 9698
# Episode 13629/15000: Epsilon = 0.0011
#
# Episode 13630/15000: Total reward = -100
# Episode 13630/15000: Epsilon = 0.0011
#
# Episode 13631/15000: Total reward = 5233
# Episode 13631/15000: Epsilon = 0.0011
#
# Episode 13632/15000: Total reward = 9259
# Episode 13632/15000: Epsilon = 0.0011
#
# Episode 13633/15000: Total reward = 9800
# Episode 13633/15000: Epsilon = 0.0011
#
# Episode 13634/15000: Total reward = 100
# Episode 13634/15000: Epsilon = 0.0011
#
# Episode 13635/15000: Total reward = 0
# Episode 13635/15000: Epsilon = 0.0011
#
# Episode 13636/15000: Total reward = 9698
# Episode 13636/15000: Epsilon = 0.0011
#
# Episode 13637/15000: Total reward = 9596
# Episode 13637/15000: Epsilon = 0.0011
#
# Episode 13638/15000: Total reward = 9800
# Episode 13638/15000: Epsilon = 0.0011
#
# Episode 13639/15000: Total reward = 0
# Episode 13639/15000: Epsilon = 0.0011
#
# Episode 13640/15000: Total reward = 198
# Episode 13640/15000: Epsilon = 0.0011
#
# Episode 13641/15000: Total reward = 0
# Episode 13641/15000: Epsilon = 0.0011
#
# Episode 13642/15000: Total reward = -51
# Episode 13642/15000: Epsilon = 0.0011
#
# Episode 13643/15000: Total reward = 9800
# Episode 13643/15000: Epsilon = 0.0011
#
# Episode 13644/15000: Total reward = 100
# Episode 13644/15000: Epsilon = 0.0011
#
# Episode 13645/15000: Total reward = 9800
# Episode 13645/15000: Epsilon = 0.0011
#
# Episode 13646/15000: Total reward = 100
# Episode 13646/15000: Epsilon = 0.0011
#
# Episode 13647/15000: Total reward = 9698
# Episode 13647/15000: Epsilon = 0.0011
#
# Episode 13648/15000: Total reward = 9800
# Episode 13648/15000: Epsilon = 0.0011
#
# Episode 13649/15000: Total reward = 9749
# Episode 13649/15000: Epsilon = 0.0011
#
# Episode 13650/15000: Total reward = 0
# Episode 13650/15000: Epsilon = 0.0011
#
# Episode 13651/15000: Total reward = 3673
# Episode 13651/15000: Epsilon = 0.0011
#
# Episode 13652/15000: Total reward = 9749
# Episode 13652/15000: Epsilon = 0.0011
#
# Episode 13653/15000: Total reward = 9800
# Episode 13653/15000: Epsilon = 0.0011
#
# Episode 13654/15000: Total reward = 9800
# Episode 13654/15000: Epsilon = 0.0011
#
# Episode 13655/15000: Total reward = 9800
# Episode 13655/15000: Epsilon = 0.0011
#
# Episode 13656/15000: Total reward = 9800
# Episode 13656/15000: Epsilon = 0.0011
#
# Episode 13657/15000: Total reward = 9800
# Episode 13657/15000: Epsilon = 0.0011
#
# Episode 13658/15000: Total reward = 9800
# Episode 13658/15000: Epsilon = 0.0011
#
# Episode 13659/15000: Total reward = 9749
# Episode 13659/15000: Epsilon = 0.0011
#
# Episode 13660/15000: Total reward = 149
# Episode 13660/15000: Epsilon = 0.0011
#
# Episode 13661/15000: Total reward = 149
# Episode 13661/15000: Epsilon = 0.0011
#
# Episode 13662/15000: Total reward = 149
# Episode 13662/15000: Epsilon = 0.0011
#
# Episode 13663/15000: Total reward = 149
# Episode 13663/15000: Epsilon = 0.0011
#
# Episode 13664/15000: Total reward = 9647
# Episode 13664/15000: Epsilon = 0.0011
#
# Episode 13665/15000: Total reward = 149
# Episode 13665/15000: Epsilon = 0.0011
#
# Episode 13666/15000: Total reward = 9800
# Episode 13666/15000: Epsilon = 0.0011
#
# Episode 13667/15000: Total reward = 9596
# Episode 13667/15000: Epsilon = 0.0011
#
# Episode 13668/15000: Total reward = 9800
# Episode 13668/15000: Epsilon = 0.0011
#
# Episode 13669/15000: Total reward = -51
# Episode 13669/15000: Epsilon = 0.0011
#
# Episode 13670/15000: Total reward = 0
# Episode 13670/15000: Epsilon = 0.0011
#
# Episode 13671/15000: Total reward = -51
# Episode 13671/15000: Epsilon = 0.0011
#
# Episode 13672/15000: Total reward = 9749
# Episode 13672/15000: Epsilon = 0.0011
#
# Episode 13673/15000: Total reward = 5880
# Episode 13673/15000: Epsilon = 0.0011
#
# Episode 13674/15000: Total reward = 0
# Episode 13674/15000: Epsilon = 0.0011
#
# Episode 13675/15000: Total reward = 9800
# Episode 13675/15000: Epsilon = 0.0011
#
# Episode 13676/15000: Total reward = 9800
# Episode 13676/15000: Epsilon = 0.0011
#
# Episode 13677/15000: Total reward = 0
# Episode 13677/15000: Epsilon = 0.0011
#
# Episode 13678/15000: Total reward = 9749
# Episode 13678/15000: Epsilon = 0.0011
#
# Episode 13679/15000: Total reward = -51
# Episode 13679/15000: Epsilon = 0.0011
#
# Episode 13680/15000: Total reward = -51
# Episode 13680/15000: Epsilon = 0.0011
#
# Episode 13681/15000: Total reward = 9698
# Episode 13681/15000: Epsilon = 0.0011
#
# Episode 13682/15000: Total reward = -51
# Episode 13682/15000: Epsilon = 0.0011
#
# Episode 13683/15000: Total reward = 0
# Episode 13683/15000: Epsilon = 0.0011
#
# Episode 13684/15000: Total reward = 9800
# Episode 13684/15000: Epsilon = 0.0011
#
# Episode 13685/15000: Total reward = 100
# Episode 13685/15000: Epsilon = 0.0011
#
# Episode 13686/15000: Total reward = -100
# Episode 13686/15000: Epsilon = 0.0011
#
# Episode 13687/15000: Total reward = 9800
# Episode 13687/15000: Epsilon = 0.0011
#
# Episode 13688/15000: Total reward = 9392
# Episode 13688/15000: Epsilon = 0.0011
#
# Episode 13689/15000: Total reward = 9114
# Episode 13689/15000: Epsilon = 0.0011
#
# Episode 13690/15000: Total reward = 1272
# Episode 13690/15000: Epsilon = 0.0011
#
# Episode 13691/15000: Total reward = 149
# Episode 13691/15000: Epsilon = 0.0011
#
# Episode 13692/15000: Total reward = 149
# Episode 13692/15000: Epsilon = 0.0011
#
# Episode 13693/15000: Total reward = 9443
# Episode 13693/15000: Epsilon = 0.0011
#
# Episode 13694/15000: Total reward = 149
# Episode 13694/15000: Epsilon = 0.0011
#
# Episode 13695/15000: Total reward = 0
# Episode 13695/15000: Epsilon = 0.0011
#
# Episode 13696/15000: Total reward = 9749
# Episode 13696/15000: Epsilon = 0.0011
#
# Episode 13697/15000: Total reward = -51
# Episode 13697/15000: Epsilon = 0.0011
#
# Episode 13698/15000: Total reward = 9749
# Episode 13698/15000: Epsilon = 0.0011
#
# Episode 13699/15000: Total reward = 9800
# Episode 13699/15000: Epsilon = 0.0011
#
# Episode 13700/15000: Total reward = 9800
# Episode 13700/15000: Epsilon = 0.0011
#
# Episode 13701/15000: Total reward = 682
# Episode 13701/15000: Epsilon = 0.0011
#
# Episode 13702/15000: Total reward = -51
# Episode 13702/15000: Epsilon = 0.0011
#
# Episode 13703/15000: Total reward = 9392
# Episode 13703/15000: Epsilon = 0.0011
#
# Episode 13704/15000: Total reward = 149
# Episode 13704/15000: Epsilon = 0.0011
#
# Episode 13705/15000: Total reward = 9698
# Episode 13705/15000: Epsilon = 0.0011
#
# Episode 13706/15000: Total reward = 9698
# Episode 13706/15000: Epsilon = 0.0011
#
# Episode 13707/15000: Total reward = 9749
# Episode 13707/15000: Epsilon = 0.0011
#
# Episode 13708/15000: Total reward = -51
# Episode 13708/15000: Epsilon = 0.0011
#
# Episode 13709/15000: Total reward = -51
# Episode 13709/15000: Epsilon = 0.0011
#
# Episode 13710/15000: Total reward = 9800
# Episode 13710/15000: Epsilon = 0.0011
#
# Episode 13711/15000: Total reward = 9749
# Episode 13711/15000: Epsilon = 0.0011
#
# Episode 13712/15000: Total reward = 0
# Episode 13712/15000: Epsilon = 0.0011
#
# Episode 13713/15000: Total reward = 1248
# Episode 13713/15000: Epsilon = 0.0011
#
# Episode 13714/15000: Total reward = -100
# Episode 13714/15000: Epsilon = 0.0010
#
# Episode 13715/15000: Total reward = -51
# Episode 13715/15000: Epsilon = 0.0010
#
# Episode 13716/15000: Total reward = 100
# Episode 13716/15000: Epsilon = 0.0010
#
# Episode 13717/15000: Total reward = 198
# Episode 13717/15000: Epsilon = 0.0010
#
# Episode 13718/15000: Total reward = 5437
# Episode 13718/15000: Epsilon = 0.0010
#
# Episode 13719/15000: Total reward = 100
# Episode 13719/15000: Epsilon = 0.0010
#
# Episode 13720/15000: Total reward = 0
# Episode 13720/15000: Epsilon = 0.0010
#
# Episode 13721/15000: Total reward = 100
# Episode 13721/15000: Epsilon = 0.0010
#
# Episode 13722/15000: Total reward = 149
# Episode 13722/15000: Epsilon = 0.0010
#
# Episode 13723/15000: Total reward = 9800
# Episode 13723/15000: Epsilon = 0.0010
#
# Episode 13724/15000: Total reward = 100
# Episode 13724/15000: Epsilon = 0.0010
#
# Episode 13725/15000: Total reward = 0
# Episode 13725/15000: Epsilon = 0.0010
#
# Episode 13726/15000: Total reward = 9698
# Episode 13726/15000: Epsilon = 0.0010
#
# Episode 13727/15000: Total reward = 149
# Episode 13727/15000: Epsilon = 0.0010
#
# Episode 13728/15000: Total reward = 6319
# Episode 13728/15000: Epsilon = 0.0010
#
# Episode 13729/15000: Total reward = 9800
# Episode 13729/15000: Epsilon = 0.0010
#
# Episode 13730/15000: Total reward = 100
# Episode 13730/15000: Epsilon = 0.0010
#
# Episode 13731/15000: Total reward = 0
# Episode 13731/15000: Epsilon = 0.0010
#
# Episode 13732/15000: Total reward = 9392
# Episode 13732/15000: Epsilon = 0.0010
#
# Episode 13733/15000: Total reward = 9800
# Episode 13733/15000: Epsilon = 0.0010
#
# Episode 13734/15000: Total reward = 9647
# Episode 13734/15000: Epsilon = 0.0010
#
# Episode 13735/15000: Total reward = 9800
# Episode 13735/15000: Epsilon = 0.0010
#
# Episode 13736/15000: Total reward = 9494
# Episode 13736/15000: Epsilon = 0.0010
#
# Episode 13737/15000: Total reward = 7301
# Episode 13737/15000: Epsilon = 0.0010
#
# Episode 13738/15000: Total reward = 100
# Episode 13738/15000: Epsilon = 0.0010
#
# Episode 13739/15000: Total reward = 9800
# Episode 13739/15000: Epsilon = 0.0010
#
# Episode 13740/15000: Total reward = 9800
# Episode 13740/15000: Epsilon = 0.0010
#
# Episode 13741/15000: Total reward = -51
# Episode 13741/15000: Epsilon = 0.0010
#
# Episode 13742/15000: Total reward = 149
# Episode 13742/15000: Epsilon = 0.0010
#
# Episode 13743/15000: Total reward = 100
# Episode 13743/15000: Epsilon = 0.0010
#
# Episode 13744/15000: Total reward = 9749
# Episode 13744/15000: Epsilon = 0.0010
#
# Episode 13745/15000: Total reward = 9800
# Episode 13745/15000: Epsilon = 0.0010
#
# Episode 13746/15000: Total reward = 100
# Episode 13746/15000: Epsilon = 0.0010
#
# Episode 13747/15000: Total reward = 0
# Episode 13747/15000: Epsilon = 0.0010
#
# Episode 13748/15000: Total reward = 9545
# Episode 13748/15000: Epsilon = 0.0010
#
# Episode 13749/15000: Total reward = 9800
# Episode 13749/15000: Epsilon = 0.0010
#
# Episode 13750/15000: Total reward = 9800
# Episode 13750/15000: Epsilon = 0.0010
#
# Episode 13751/15000: Total reward = 0
# Episode 13751/15000: Epsilon = 0.0010
#
# Episode 13752/15000: Total reward = 100
# Episode 13752/15000: Epsilon = 0.0010
#
# Episode 13753/15000: Total reward = -51
# Episode 13753/15000: Epsilon = 0.0010
#
# Episode 13754/15000: Total reward = 9800
# Episode 13754/15000: Epsilon = 0.0010
#
# Episode 13755/15000: Total reward = 100
# Episode 13755/15000: Epsilon = 0.0010
#
# Episode 13756/15000: Total reward = 100
# Episode 13756/15000: Epsilon = 0.0010
#
# Episode 13757/15000: Total reward = 9800
# Episode 13757/15000: Epsilon = 0.0010
#
# Episode 13758/15000: Total reward = -51
# Episode 13758/15000: Epsilon = 0.0010
#
# Episode 13759/15000: Total reward = 9749
# Episode 13759/15000: Epsilon = 0.0010
#
# Episode 13760/15000: Total reward = 9239
# Episode 13760/15000: Epsilon = 0.0010
#
# Episode 13761/15000: Total reward = -51
# Episode 13761/15000: Epsilon = 0.0010
#
# Episode 13762/15000: Total reward = -51
# Episode 13762/15000: Epsilon = 0.0010
#
# Episode 13763/15000: Total reward = 0
# Episode 13763/15000: Epsilon = 0.0010
#
# Episode 13764/15000: Total reward = 9749
# Episode 13764/15000: Epsilon = 0.0010
#
# Episode 13765/15000: Total reward = 9800
# Episode 13765/15000: Epsilon = 0.0010
#
# Episode 13766/15000: Total reward = 9800
# Episode 13766/15000: Epsilon = 0.0010
#
# Episode 13767/15000: Total reward = -51
# Episode 13767/15000: Epsilon = 0.0010
#
# Episode 13768/15000: Total reward = 9800
# Episode 13768/15000: Epsilon = 0.0010
#
# Episode 13769/15000: Total reward = 9596
# Episode 13769/15000: Epsilon = 0.0010
#
# Episode 13770/15000: Total reward = 9800
# Episode 13770/15000: Epsilon = 0.0010
#
# Episode 13771/15000: Total reward = 9239
# Episode 13771/15000: Epsilon = 0.0010
#
# Episode 13772/15000: Total reward = 9800
# Episode 13772/15000: Epsilon = 0.0010
#
# Episode 13773/15000: Total reward = 9800
# Episode 13773/15000: Epsilon = 0.0010
#
# Episode 13774/15000: Total reward = 0
# Episode 13774/15000: Epsilon = 0.0010
#
# Episode 13775/15000: Total reward = 9800
# Episode 13775/15000: Epsilon = 0.0010
#
# Episode 13776/15000: Total reward = 9800
# Episode 13776/15000: Epsilon = 0.0010
#
# Episode 13777/15000: Total reward = 9749
# Episode 13777/15000: Epsilon = 0.0010
#
# Episode 13778/15000: Total reward = 729
# Episode 13778/15000: Epsilon = 0.0010
#
# Episode 13779/15000: Total reward = 9443
# Episode 13779/15000: Epsilon = 0.0010
#
# Episode 13780/15000: Total reward = 0
# Episode 13780/15000: Epsilon = 0.0010
#
# Episode 13781/15000: Total reward = 9800
# Episode 13781/15000: Epsilon = 0.0010
#
# Episode 13782/15000: Total reward = -51
# Episode 13782/15000: Epsilon = 0.0010
#
# Episode 13783/15000: Total reward = -51
# Episode 13783/15000: Epsilon = 0.0010
#
# Episode 13784/15000: Total reward = 9545
# Episode 13784/15000: Epsilon = 0.0010
#
# Episode 13785/15000: Total reward = 149
# Episode 13785/15000: Epsilon = 0.0010
#
# Episode 13786/15000: Total reward = -51
# Episode 13786/15000: Epsilon = 0.0010
#
# Episode 13787/15000: Total reward = 9749
# Episode 13787/15000: Epsilon = 0.0010
#
# Episode 13788/15000: Total reward = 198
# Episode 13788/15000: Epsilon = 0.0010
#
# Episode 13789/15000: Total reward = 9800
# Episode 13789/15000: Epsilon = 0.0010
#
# Episode 13790/15000: Total reward = 9749
# Episode 13790/15000: Epsilon = 0.0010
#
# Episode 13791/15000: Total reward = 9596
# Episode 13791/15000: Epsilon = 0.0010
#
# Episode 13792/15000: Total reward = 9749
# Episode 13792/15000: Epsilon = 0.0010
#
# Episode 13793/15000: Total reward = 149
# Episode 13793/15000: Epsilon = 0.0010
#
# Episode 13794/15000: Total reward = 9800
# Episode 13794/15000: Epsilon = 0.0010
#
# Episode 13795/15000: Total reward = -51
# Episode 13795/15000: Epsilon = 0.0010
#
# Episode 13796/15000: Total reward = 9749
# Episode 13796/15000: Epsilon = 0.0010
#
# Episode 13797/15000: Total reward = 149
# Episode 13797/15000: Epsilon = 0.0010
#
# Episode 13798/15000: Total reward = 0
# Episode 13798/15000: Epsilon = 0.0010
#
# Episode 13799/15000: Total reward = 9800
# Episode 13799/15000: Epsilon = 0.0010
#
# Episode 13800/15000: Total reward = 100
# Episode 13800/15000: Epsilon = 0.0010
#
# Episode 13801/15000: Total reward = 9494
# Episode 13801/15000: Epsilon = 0.0010
#
# Episode 13802/15000: Total reward = 9647
# Episode 13802/15000: Epsilon = 0.0010
#
# Episode 13803/15000: Total reward = 0
# Episode 13803/15000: Epsilon = 0.0010
#
# Episode 13804/15000: Total reward = 9800
# Episode 13804/15000: Epsilon = 0.0010
#
# Episode 13805/15000: Total reward = 149
# Episode 13805/15000: Epsilon = 0.0010
#
# Episode 13806/15000: Total reward = 9800
# Episode 13806/15000: Epsilon = 0.0010
#
# Episode 13807/15000: Total reward = 9800
# Episode 13807/15000: Epsilon = 0.0010
#
# Episode 13808/15000: Total reward = 9800
# Episode 13808/15000: Epsilon = 0.0010
#
# Episode 13809/15000: Total reward = 9800
# Episode 13809/15000: Epsilon = 0.0010
#
# Episode 13810/15000: Total reward = 9800
# Episode 13810/15000: Epsilon = 0.0010
#
# Episode 13811/15000: Total reward = 9800
# Episode 13811/15000: Epsilon = 0.0010
#
# Episode 13812/15000: Total reward = 0
# Episode 13812/15000: Epsilon = 0.0010
#
# Episode 13813/15000: Total reward = 9800
# Episode 13813/15000: Epsilon = 0.0010
#
# Episode 13814/15000: Total reward = 9800
# Episode 13814/15000: Epsilon = 0.0010
#
# Episode 13815/15000: Total reward = 0
# Episode 13815/15000: Epsilon = 0.0010
#
# Episode 13816/15000: Total reward = 198
# Episode 13816/15000: Epsilon = 0.0010
#
# Episode 13817/15000: Total reward = 9800
# Episode 13817/15000: Epsilon = 0.0010
#
# Episode 13818/15000: Total reward = 9749
# Episode 13818/15000: Epsilon = 0.0010
#
# Episode 13819/15000: Total reward = 9800
# Episode 13819/15000: Epsilon = 0.0010
#
# Episode 13820/15000: Total reward = 9749
# Episode 13820/15000: Epsilon = 0.0010
#
# Episode 13821/15000: Total reward = 9800
# Episode 13821/15000: Epsilon = 0.0010
#
# Episode 13822/15000: Total reward = 7252
# Episode 13822/15000: Epsilon = 0.0010
#
# Episode 13823/15000: Total reward = 100
# Episode 13823/15000: Epsilon = 0.0010
#
# Episode 13824/15000: Total reward = 9647
# Episode 13824/15000: Epsilon = 0.0010
#
# Episode 13825/15000: Total reward = 9800
# Episode 13825/15000: Epsilon = 0.0010
#
# Episode 13826/15000: Total reward = 9749
# Episode 13826/15000: Epsilon = 0.0010
#
# Episode 13827/15000: Total reward = -51
# Episode 13827/15000: Epsilon = 0.0010
#
# Episode 13828/15000: Total reward = 9749
# Episode 13828/15000: Epsilon = 0.0010
#
# Episode 13829/15000: Total reward = 9749
# Episode 13829/15000: Epsilon = 0.0010
#
# Episode 13830/15000: Total reward = 0
# Episode 13830/15000: Epsilon = 0.0010
#
# Episode 13831/15000: Total reward = 9800
# Episode 13831/15000: Epsilon = 0.0010
#
# Episode 13832/15000: Total reward = 9800
# Episode 13832/15000: Epsilon = 0.0010
#
# Episode 13833/15000: Total reward = 149
# Episode 13833/15000: Epsilon = 0.0010
#
# Episode 13834/15000: Total reward = 9800
# Episode 13834/15000: Epsilon = 0.0010
#
# Episode 13835/15000: Total reward = 149
# Episode 13835/15000: Epsilon = 0.0010
#
# Episode 13836/15000: Total reward = 9800
# Episode 13836/15000: Epsilon = 0.0010
#
# Episode 13837/15000: Total reward = 9749
# Episode 13837/15000: Epsilon = 0.0010
#
# Episode 13838/15000: Total reward = 100
# Episode 13838/15000: Epsilon = 0.0010
#
# Episode 13839/15000: Total reward = 9800
# Episode 13839/15000: Epsilon = 0.0010
#
# Episode 13840/15000: Total reward = -51
# Episode 13840/15000: Epsilon = 0.0010
#
# Episode 13841/15000: Total reward = 8718
# Episode 13841/15000: Epsilon = 0.0010
#
# Episode 13842/15000: Total reward = 100
# Episode 13842/15000: Epsilon = 0.0010
#
# Episode 13843/15000: Total reward = -51
# Episode 13843/15000: Epsilon = 0.0010
#
# Episode 13844/15000: Total reward = 9800
# Episode 13844/15000: Epsilon = 0.0010
#
# Episode 13845/15000: Total reward = 0
# Episode 13845/15000: Epsilon = 0.0010
#
# Episode 13846/15000: Total reward = 9800
# Episode 13846/15000: Epsilon = 0.0010
#
# Episode 13847/15000: Total reward = 100
# Episode 13847/15000: Epsilon = 0.0010
#
# Episode 13848/15000: Total reward = 9800
# Episode 13848/15000: Epsilon = 0.0010
#
# Episode 13849/15000: Total reward = 9800
# Episode 13849/15000: Epsilon = 0.0010
#
# Episode 13850/15000: Total reward = 9800
# Episode 13850/15000: Epsilon = 0.0010
#
# Episode 13851/15000: Total reward = 9800
# Episode 13851/15000: Epsilon = 0.0010
#
# Episode 13852/15000: Total reward = 0
# Episode 13852/15000: Epsilon = 0.0010
#
# Episode 13853/15000: Total reward = 149
# Episode 13853/15000: Epsilon = 0.0010
#
# Episode 13854/15000: Total reward = 9698
# Episode 13854/15000: Epsilon = 0.0010
#
# Episode 13855/15000: Total reward = 9239
# Episode 13855/15000: Epsilon = 0.0010
#
# Episode 13856/15000: Total reward = 9800
# Episode 13856/15000: Epsilon = 0.0010
#
# Episode 13857/15000: Total reward = 9800
# Episode 13857/15000: Epsilon = 0.0010
#
# Episode 13858/15000: Total reward = 0
# Episode 13858/15000: Epsilon = 0.0010
#
# Episode 13859/15000: Total reward = 9800
# Episode 13859/15000: Epsilon = 0.0010
#
# Episode 13860/15000: Total reward = 9800
# Episode 13860/15000: Epsilon = 0.0010
#
# Episode 13861/15000: Total reward = 149
# Episode 13861/15000: Epsilon = 0.0010
#
# Episode 13862/15000: Total reward = 9239
# Episode 13862/15000: Epsilon = 0.0010
#
# Episode 13863/15000: Total reward = 9749
# Episode 13863/15000: Epsilon = 0.0010
#
# Episode 13864/15000: Total reward = 100
# Episode 13864/15000: Epsilon = 0.0010
#
# Episode 13865/15000: Total reward = 9749
# Episode 13865/15000: Epsilon = 0.0010
#
# Episode 13866/15000: Total reward = 149
# Episode 13866/15000: Epsilon = 0.0010
#
# Episode 13867/15000: Total reward = 9800
# Episode 13867/15000: Epsilon = 0.0010
#
# Episode 13868/15000: Total reward = 9698
# Episode 13868/15000: Epsilon = 0.0010
#
# Episode 13869/15000: Total reward = -51
# Episode 13869/15000: Epsilon = 0.0010
#
# Episode 13870/15000: Total reward = 198
# Episode 13870/15000: Epsilon = 0.0010
#
# Episode 13871/15000: Total reward = -100
# Episode 13871/15000: Epsilon = 0.0010
#
# Episode 13872/15000: Total reward = 9749
# Episode 13872/15000: Epsilon = 0.0010
#
# Episode 13873/15000: Total reward = 9800
# Episode 13873/15000: Epsilon = 0.0010
#
# Episode 13874/15000: Total reward = 9800
# Episode 13874/15000: Epsilon = 0.0010
#
# Episode 13875/15000: Total reward = 9647
# Episode 13875/15000: Epsilon = 0.0010
#
# Episode 13876/15000: Total reward = 100
# Episode 13876/15000: Epsilon = 0.0010
#
# Episode 13877/15000: Total reward = 9698
# Episode 13877/15000: Epsilon = 0.0010
#
# Episode 13878/15000: Total reward = 9800
# Episode 13878/15000: Epsilon = 0.0010
#
# Episode 13879/15000: Total reward = -51
# Episode 13879/15000: Epsilon = 0.0010
#
# Episode 13880/15000: Total reward = 149
# Episode 13880/15000: Epsilon = 0.0010
#
# Episode 13881/15000: Total reward = 9749
# Episode 13881/15000: Epsilon = 0.0010
#
# Episode 13882/15000: Total reward = 9749
# Episode 13882/15000: Epsilon = 0.0010
#
# Episode 13883/15000: Total reward = 9749
# Episode 13883/15000: Epsilon = 0.0010
#
# Episode 13884/15000: Total reward = 100
# Episode 13884/15000: Epsilon = 0.0010
#
# Episode 13885/15000: Total reward = 7740
# Episode 13885/15000: Epsilon = 0.0010
#
# Episode 13886/15000: Total reward = 9800
# Episode 13886/15000: Epsilon = 0.0010
#
# Episode 13887/15000: Total reward = 4849
# Episode 13887/15000: Epsilon = 0.0010
#
# Episode 13888/15000: Total reward = 8769
# Episode 13888/15000: Epsilon = 0.0010
#
# Episode 13889/15000: Total reward = 9800
# Episode 13889/15000: Epsilon = 0.0010
#
# Episode 13890/15000: Total reward = 6613
# Episode 13890/15000: Epsilon = 0.0010
#
# Episode 13891/15000: Total reward = 9800
# Episode 13891/15000: Epsilon = 0.0010
#
# Episode 13892/15000: Total reward = 9800
# Episode 13892/15000: Epsilon = 0.0010
#
# Episode 13893/15000: Total reward = 0
# Episode 13893/15000: Epsilon = 0.0010
#
# Episode 13894/15000: Total reward = 9800
# Episode 13894/15000: Epsilon = 0.0010
#
# Episode 13895/15000: Total reward = 9800
# Episode 13895/15000: Epsilon = 0.0010
#
# Episode 13896/15000: Total reward = 9749
# Episode 13896/15000: Epsilon = 0.0010
#
# Episode 13897/15000: Total reward = 149
# Episode 13897/15000: Epsilon = 0.0010
#
# Episode 13898/15000: Total reward = 100
# Episode 13898/15000: Epsilon = 0.0010
#
# Episode 13899/15000: Total reward = 9290
# Episode 13899/15000: Epsilon = 0.0010
#
# Episode 13900/15000: Total reward = 9698
# Episode 13900/15000: Epsilon = 0.0010
#
# Episode 13901/15000: Total reward = 9800
# Episode 13901/15000: Epsilon = 0.0010
#
# Episode 13902/15000: Total reward = 9800
# Episode 13902/15000: Epsilon = 0.0010
#
# Episode 13903/15000: Total reward = 3765
# Episode 13903/15000: Epsilon = 0.0010
#
# Episode 13904/15000: Total reward = 149
# Episode 13904/15000: Epsilon = 0.0010
#
# Episode 13905/15000: Total reward = 9800
# Episode 13905/15000: Epsilon = 0.0010
#
# Episode 13906/15000: Total reward = 9749
# Episode 13906/15000: Epsilon = 0.0010
#
# Episode 13907/15000: Total reward = -51
# Episode 13907/15000: Epsilon = 0.0010
#
# Episode 13908/15000: Total reward = 149
# Episode 13908/15000: Epsilon = 0.0010
#
# Episode 13909/15000: Total reward = 9800
# Episode 13909/15000: Epsilon = 0.0010
#
# Episode 13910/15000: Total reward = 9749
# Episode 13910/15000: Epsilon = 0.0010
#
# Episode 13911/15000: Total reward = 9698
# Episode 13911/15000: Epsilon = 0.0010
#
# Episode 13912/15000: Total reward = -51
# Episode 13912/15000: Epsilon = 0.0010
#
# Episode 13913/15000: Total reward = 9800
# Episode 13913/15000: Epsilon = 0.0010
#
# Episode 13914/15000: Total reward = 1095
# Episode 13914/15000: Epsilon = 0.0010
#
# Episode 13915/15000: Total reward = 4504
# Episode 13915/15000: Epsilon = 0.0010
#
# Episode 13916/15000: Total reward = 9800
# Episode 13916/15000: Epsilon = 0.0010
#
# Episode 13917/15000: Total reward = 9749
# Episode 13917/15000: Epsilon = 0.0010
#
# Episode 13918/15000: Total reward = 9749
# Episode 13918/15000: Epsilon = 0.0010
#
# Episode 13919/15000: Total reward = 9392
# Episode 13919/15000: Epsilon = 0.0010
#
# Episode 13920/15000: Total reward = 9698
# Episode 13920/15000: Epsilon = 0.0010
#
# Episode 13921/15000: Total reward = 9749
# Episode 13921/15000: Epsilon = 0.0010
#
# Episode 13922/15000: Total reward = 100
# Episode 13922/15000: Epsilon = 0.0010
#
# Episode 13923/15000: Total reward = 100
# Episode 13923/15000: Epsilon = 0.0010
#
# Episode 13924/15000: Total reward = 9749
# Episode 13924/15000: Epsilon = 0.0010
#
# Episode 13925/15000: Total reward = 9800
# Episode 13925/15000: Epsilon = 0.0010
#
# Episode 13926/15000: Total reward = 9800
# Episode 13926/15000: Epsilon = 0.0010
#
# Episode 13927/15000: Total reward = 9698
# Episode 13927/15000: Epsilon = 0.0010
#
# Episode 13928/15000: Total reward = 9800
# Episode 13928/15000: Epsilon = 0.0010
#
# Episode 13929/15000: Total reward = 2056
# Episode 13929/15000: Epsilon = 0.0010
#
# Episode 13930/15000: Total reward = 9749
# Episode 13930/15000: Epsilon = 0.0010
#
# Episode 13931/15000: Total reward = -100
# Episode 13931/15000: Epsilon = 0.0010
#
# Episode 13932/15000: Total reward = 9749
# Episode 13932/15000: Epsilon = 0.0010
#
# Episode 13933/15000: Total reward = 9290
# Episode 13933/15000: Epsilon = 0.0010
#
# Episode 13934/15000: Total reward = 9749
# Episode 13934/15000: Epsilon = 0.0010
#
# Episode 13935/15000: Total reward = -51
# Episode 13935/15000: Epsilon = 0.0010
#
# ...
# Episode 14798/15000: Epsilon = 0.0010
#
# Episode 14799/15000: Total reward = 9800
# Episode 14799/15000: Epsilon = 0.0010
#
# Episode 14800/15000: Total reward = 9749
# Episode 14800/15000: Epsilon = 0.0010
#
# Episode 14801/15000: Total reward = 100
# Episode 14801/15000: Epsilon = 0.0010
#
# Episode 14802/15000: Total reward = 149
# Episode 14802/15000: Epsilon = 0.0010
#
# Episode 14803/15000: Total reward = 9749
# Episode 14803/15000: Epsilon = 0.0010
#
# Episode 14804/15000: Total reward = 100
# Episode 14804/15000: Epsilon = 0.0010
#
# Episode 14805/15000: Total reward = 9188
# Episode 14805/15000: Epsilon = 0.0010
#
# Episode 14806/15000: Total reward = 9800
# Episode 14806/15000: Epsilon = 0.0010
#
# Episode 14807/15000: Total reward = 9800
# Episode 14807/15000: Epsilon = 0.0010
#
# Episode 14808/15000: Total reward = 9800
# Episode 14808/15000: Epsilon = 0.0010
#
# Episode 14809/15000: Total reward = 0
# Episode 14809/15000: Epsilon = 0.0010
#
# Episode 14810/15000: Total reward = 9749
# Episode 14810/15000: Epsilon = 0.0010
#
# Episode 14811/15000: Total reward = 9749
# Episode 14811/15000: Epsilon = 0.0010
#
# Episode 14812/15000: Total reward = 100
# Episode 14812/15000: Epsilon = 0.0010
#
# Episode 14813/15000: Total reward = 9749
# Episode 14813/15000: Epsilon = 0.0010
#
# Episode 14814/15000: Total reward = 149
# Episode 14814/15000: Epsilon = 0.0010
#
# Episode 14815/15000: Total reward = 149
# Episode 14815/15000: Epsilon = 0.0010
#
# Episode 14816/15000: Total reward = 9749
# Episode 14816/15000: Epsilon = 0.0010
#
# Episode 14817/15000: Total reward = 9800
# Episode 14817/15000: Epsilon = 0.0010
#
# Episode 14818/15000: Total reward = 1127
# Episode 14818/15000: Epsilon = 0.0010
#
# Episode 14819/15000: Total reward = 9800
# Episode 14819/15000: Epsilon = 0.0010
#
# Episode 14820/15000: Total reward = 9800
# Episode 14820/15000: Epsilon = 0.0010
#
# Episode 14821/15000: Total reward = 100
# Episode 14821/15000: Epsilon = 0.0010
#
# Episode 14822/15000: Total reward = 0
# Episode 14822/15000: Epsilon = 0.0010
#
# Episode 14823/15000: Total reward = 7838
# Episode 14823/15000: Epsilon = 0.0010
#
# Episode 14824/15000: Total reward = 100
# Episode 14824/15000: Epsilon = 0.0010
#
# Episode 14825/15000: Total reward = 9800
# Episode 14825/15000: Epsilon = 0.0010
#
# Episode 14826/15000: Total reward = 9749
# Episode 14826/15000: Epsilon = 0.0010
#
# Episode 14827/15000: Total reward = 9800
# Episode 14827/15000: Epsilon = 0.0010
#
# Episode 14828/15000: Total reward = -51
# Episode 14828/15000: Epsilon = 0.0010
#
# Episode 14829/15000: Total reward = 100
# Episode 14829/15000: Epsilon = 0.0010
#
# Episode 14830/15000: Total reward = 9698
# Episode 14830/15000: Epsilon = 0.0010
#
# Episode 14831/15000: Total reward = 9800
# Episode 14831/15000: Epsilon = 0.0010
#
# Episode 14832/15000: Total reward = -51
# Episode 14832/15000: Epsilon = 0.0010
#
# Episode 14833/15000: Total reward = 9749
# Episode 14833/15000: Epsilon = 0.0010
#
# Episode 14834/15000: Total reward = 100
# Episode 14834/15000: Epsilon = 0.0010
#
# Episode 14835/15000: Total reward = 9749
# Episode 14835/15000: Epsilon = 0.0010
#
# Episode 14836/15000: Total reward = 9749
# Episode 14836/15000: Epsilon = 0.0010
#
# Episode 14837/15000: Total reward = -51
# Episode 14837/15000: Epsilon = 0.0010
#
# Episode 14838/15000: Total reward = 9800
# Episode 14838/15000: Epsilon = 0.0010
#
# Episode 14839/15000: Total reward = 9800
# Episode 14839/15000: Epsilon = 0.0010
#
# Episode 14840/15000: Total reward = -51
# Episode 14840/15000: Epsilon = 0.0010
#
# Episode 14841/15000: Total reward = 0
# Episode 14841/15000: Epsilon = 0.0010
#
# Episode 14842/15000: Total reward = -51
# Episode 14842/15000: Epsilon = 0.0010
#
# Episode 14843/15000: Total reward = -51
# Episode 14843/15000: Epsilon = 0.0010
#
# Episode 14844/15000: Total reward = 9800
# Episode 14844/15000: Epsilon = 0.0010
#
# Episode 14845/15000: Total reward = 9749
# Episode 14845/15000: Epsilon = 0.0010
#
# Episode 14846/15000: Total reward = -100
# Episode 14846/15000: Epsilon = 0.0010
#
# Episode 14847/15000: Total reward = 9749
# Episode 14847/15000: Epsilon = 0.0010
#
# Episode 14848/15000: Total reward = -51
# Episode 14848/15000: Epsilon = 0.0010
#
# Episode 14849/15000: Total reward = 9800
# Episode 14849/15000: Epsilon = 0.0010
#
# Episode 14850/15000: Total reward = 100
# Episode 14850/15000: Epsilon = 0.0010
#
# Episode 14851/15000: Total reward = 6264
# Episode 14851/15000: Epsilon = 0.0010
#
# Episode 14852/15000: Total reward = -51
# Episode 14852/15000: Epsilon = 0.0010
#
# Episode 14853/15000: Total reward = 0
# Episode 14853/15000: Epsilon = 0.0010
#
# Episode 14854/15000: Total reward = 9800
# Episode 14854/15000: Epsilon = 0.0010
#
# Episode 14855/15000: Total reward = 9800
# Episode 14855/15000: Epsilon = 0.0010
#
# Episode 14856/15000: Total reward = 9596
# Episode 14856/15000: Epsilon = 0.0010
#
# Episode 14857/15000: Total reward = -51
# Episode 14857/15000: Epsilon = 0.0010
#
# Episode 14858/15000: Total reward = 9545
# Episode 14858/15000: Epsilon = 0.0010
#
# Episode 14859/15000: Total reward = 9800
# Episode 14859/15000: Epsilon = 0.0010
#
# Episode 14860/15000: Total reward = 149
# Episode 14860/15000: Epsilon = 0.0010
#
# Episode 14861/15000: Total reward = 0
# Episode 14861/15000: Epsilon = 0.0010
#
# Episode 14862/15000: Total reward = -51
# Episode 14862/15000: Epsilon = 0.0010
#
# Episode 14863/15000: Total reward = -100
# Episode 14863/15000: Epsilon = 0.0010
#
# Episode 14864/15000: Total reward = 4651
# Episode 14864/15000: Epsilon = 0.0010
#
# Episode 14865/15000: Total reward = 100
# Episode 14865/15000: Epsilon = 0.0010
#
# Episode 14866/15000: Total reward = 9749
# Episode 14866/15000: Epsilon = 0.0010
#
# Episode 14867/15000: Total reward = -51
# Episode 14867/15000: Epsilon = 0.0010
#
# Episode 14868/15000: Total reward = 198
# Episode 14868/15000: Epsilon = 0.0010
#
# Episode 14869/15000: Total reward = 9800
# Episode 14869/15000: Epsilon = 0.0010
#
# Episode 14870/15000: Total reward = 149
# Episode 14870/15000: Epsilon = 0.0010
#
# Episode 14871/15000: Total reward = 9749
# Episode 14871/15000: Epsilon = 0.0010
#
# Episode 14872/15000: Total reward = 9494
# Episode 14872/15000: Epsilon = 0.0010
#
# Episode 14873/15000: Total reward = 9800
# Episode 14873/15000: Epsilon = 0.0010
#
# Episode 14874/15000: Total reward = 9800
# Episode 14874/15000: Epsilon = 0.0010
#
# Episode 14875/15000: Total reward = 9800
# Episode 14875/15000: Epsilon = 0.0010
#
# Episode 14876/15000: Total reward = 9800
# Episode 14876/15000: Epsilon = 0.0010
#
# Episode 14877/15000: Total reward = -51
# Episode 14877/15000: Epsilon = 0.0010
#
# Episode 14878/15000: Total reward = 9800
# Episode 14878/15000: Epsilon = 0.0010
#
# Episode 14879/15000: Total reward = 9494
# Episode 14879/15000: Epsilon = 0.0010
#
# Episode 14880/15000: Total reward = 0
# Episode 14880/15000: Epsilon = 0.0010
#
# Episode 14881/15000: Total reward = 9698
# Episode 14881/15000: Epsilon = 0.0010
#
# Episode 14882/15000: Total reward = -51
# Episode 14882/15000: Epsilon = 0.0010
#
# Episode 14883/15000: Total reward = 0
# Episode 14883/15000: Epsilon = 0.0010
#
# Episode 14884/15000: Total reward = 100
# Episode 14884/15000: Epsilon = 0.0010
#
# Episode 14885/15000: Total reward = 149
# Episode 14885/15000: Epsilon = 0.0010
#
# Episode 14886/15000: Total reward = 100
# Episode 14886/15000: Epsilon = 0.0010
#
# Episode 14887/15000: Total reward = 8933
# Episode 14887/15000: Epsilon = 0.0010
#
# Episode 14888/15000: Total reward = 9647
# Episode 14888/15000: Epsilon = 0.0010
#
# Episode 14889/15000: Total reward = 9749
# Episode 14889/15000: Epsilon = 0.0010
#
# Episode 14890/15000: Total reward = 9800
# Episode 14890/15000: Epsilon = 0.0010
#
# Episode 14891/15000: Total reward = 439
# Episode 14891/15000: Epsilon = 0.0010
#
# Episode 14892/15000: Total reward = 9800
# Episode 14892/15000: Epsilon = 0.0010
#
# Episode 14893/15000: Total reward = -51
# Episode 14893/15000: Epsilon = 0.0010
#
# Episode 14894/15000: Total reward = 0
# Episode 14894/15000: Epsilon = 0.0010
#
# Episode 14895/15000: Total reward = 7593
# Episode 14895/15000: Epsilon = 0.0010
#
# Episode 14896/15000: Total reward = 9800
# Episode 14896/15000: Epsilon = 0.0010
#
# Episode 14897/15000: Total reward = -51
# Episode 14897/15000: Epsilon = 0.0010
#
# Episode 14898/15000: Total reward = 0
# Episode 14898/15000: Epsilon = 0.0010
#
# Episode 14899/15000: Total reward = 9698
# Episode 14899/15000: Epsilon = 0.0010
#
# Episode 14900/15000: Total reward = 0
# Episode 14900/15000: Epsilon = 0.0010
#
# Episode 14901/15000: Total reward = 0
# Episode 14901/15000: Epsilon = 0.0010
#
# Episode 14902/15000: Total reward = 149
# Episode 14902/15000: Epsilon = 0.0010
#
# Episode 14903/15000: Total reward = 9749
# Episode 14903/15000: Epsilon = 0.0010
#
# Episode 14904/15000: Total reward = -51
# Episode 14904/15000: Epsilon = 0.0010
#
# Episode 14905/15000: Total reward = 0
# Episode 14905/15000: Epsilon = 0.0010
#
# Episode 14906/15000: Total reward = 100
# Episode 14906/15000: Epsilon = 0.0010
#
# Episode 14907/15000: Total reward = 9800
# Episode 14907/15000: Epsilon = 0.0010
#
# Episode 14908/15000: Total reward = 9749
# Episode 14908/15000: Epsilon = 0.0010
#
# Episode 14909/15000: Total reward = 9596
# Episode 14909/15000: Epsilon = 0.0010
#
# Episode 14910/15000: Total reward = -51
# Episode 14910/15000: Epsilon = 0.0010
#
# Episode 14911/15000: Total reward = 3371
# Episode 14911/15000: Epsilon = 0.0010
#
# Episode 14912/15000: Total reward = 100
# Episode 14912/15000: Epsilon = 0.0010
#
# Episode 14913/15000: Total reward = 9494
# Episode 14913/15000: Epsilon = 0.0010
#
# Episode 14914/15000: Total reward = -51
# Episode 14914/15000: Epsilon = 0.0010
#
# Episode 14915/15000: Total reward = 100
# Episode 14915/15000: Epsilon = 0.0010
#
# Episode 14916/15000: Total reward = 9749
# Episode 14916/15000: Epsilon = 0.0010
#
# Episode 14917/15000: Total reward = 2922
# Episode 14917/15000: Epsilon = 0.0010
#
# Episode 14918/15000: Total reward = 9800
# Episode 14918/15000: Epsilon = 0.0010
#
# Episode 14919/15000: Total reward = 149
# Episode 14919/15000: Epsilon = 0.0010
#
# Episode 14920/15000: Total reward = 9749
# Episode 14920/15000: Epsilon = 0.0010
#
# Episode 14921/15000: Total reward = 100
# Episode 14921/15000: Epsilon = 0.0010
#
# Episode 14922/15000: Total reward = -51
# Episode 14922/15000: Epsilon = 0.0010
#
# Episode 14923/15000: Total reward = 9800
# Episode 14923/15000: Epsilon = 0.0010
#
# Episode 14924/15000: Total reward = 9800
# Episode 14924/15000: Epsilon = 0.0010
#
# Episode 14925/15000: Total reward = 9698
# Episode 14925/15000: Epsilon = 0.0010
#
# Episode 14926/15000: Total reward = 149
# Episode 14926/15000: Epsilon = 0.0010
#
# Episode 14927/15000: Total reward = -51
# Episode 14927/15000: Epsilon = 0.0010
#
# Episode 14928/15000: Total reward = 9800
# Episode 14928/15000: Epsilon = 0.0010
#
# Episode 14929/15000: Total reward = 9800
# Episode 14929/15000: Epsilon = 0.0010
#
# Episode 14930/15000: Total reward = 149
# Episode 14930/15000: Epsilon = 0.0010
#
# Episode 14931/15000: Total reward = 9596
# Episode 14931/15000: Epsilon = 0.0010
#
# Episode 14932/15000: Total reward = 0
# Episode 14932/15000: Epsilon = 0.0010
#
# Episode 14933/15000: Total reward = -51
# Episode 14933/15000: Epsilon = 0.0010
#
# Episode 14934/15000: Total reward = 9800
# Episode 14934/15000: Epsilon = 0.0010
#
# Episode 14935/15000: Total reward = 9749
# Episode 14935/15000: Epsilon = 0.0010
#
# Episode 14936/15000: Total reward = 9494
# Episode 14936/15000: Epsilon = 0.0010
#
# Episode 14937/15000: Total reward = 9800
# Episode 14937/15000: Epsilon = 0.0010
#
# Episode 14938/15000: Total reward = 9800
# Episode 14938/15000: Epsilon = 0.0010
#
# Episode 14939/15000: Total reward = 9800
# Episode 14939/15000: Epsilon = 0.0010
#
# Episode 14940/15000: Total reward = 149
# Episode 14940/15000: Epsilon = 0.0010
#
# Episode 14941/15000: Total reward = 9749
# Episode 14941/15000: Epsilon = 0.0010
#
# Episode 14942/15000: Total reward = 9800
# Episode 14942/15000: Epsilon = 0.0010
#
# Episode 14943/15000: Total reward = -100
# Episode 14943/15000: Epsilon = 0.0010
#
# Episode 14944/15000: Total reward = 0
# Episode 14944/15000: Epsilon = 0.0010
#
# Episode 14945/15000: Total reward = 9698
# Episode 14945/15000: Epsilon = 0.0010
#
# Episode 14946/15000: Total reward = -51
# Episode 14946/15000: Epsilon = 0.0010
#
# Episode 14947/15000: Total reward = 9596
# Episode 14947/15000: Epsilon = 0.0010
#
# Episode 14948/15000: Total reward = 9800
# Episode 14948/15000: Epsilon = 0.0010
#
# Episode 14949/15000: Total reward = 9749
# Episode 14949/15000: Epsilon = 0.0010
#
# Episode 14950/15000: Total reward = 0
# Episode 14950/15000: Epsilon = 0.0010
#
# Episode 14951/15000: Total reward = 9800
# Episode 14951/15000: Epsilon = 0.0010
#
# Episode 14952/15000: Total reward = 149
# Episode 14952/15000: Epsilon = 0.0010
#
# Episode 14953/15000: Total reward = 9749
# Episode 14953/15000: Epsilon = 0.0010
#
# Episode 14954/15000: Total reward = 0
# Episode 14954/15000: Epsilon = 0.0010
#
# Episode 14955/15000: Total reward = 9800
# Episode 14955/15000: Epsilon = 0.0010
#
# Episode 14956/15000: Total reward = 100
# Episode 14956/15000: Epsilon = 0.0010
#
# Episode 14957/15000: Total reward = 9800
# Episode 14957/15000: Epsilon = 0.0010
#
# Episode 14958/15000: Total reward = 7299
# Episode 14958/15000: Epsilon = 0.0010
#
# Episode 14959/15000: Total reward = -51
# Episode 14959/15000: Epsilon = 0.0010
#
# Episode 14960/15000: Total reward = 9800
# Episode 14960/15000: Epsilon = 0.0010
#
# Episode 14961/15000: Total reward = -51
# Episode 14961/15000: Epsilon = 0.0010
#
# Episode 14962/15000: Total reward = -51
# Episode 14962/15000: Epsilon = 0.0010
#
# Episode 14963/15000: Total reward = -51
# Episode 14963/15000: Epsilon = 0.0010
#
# Episode 14964/15000: Total reward = 100
# Episode 14964/15000: Epsilon = 0.0010
#
# Episode 14965/15000: Total reward = 9749
# Episode 14965/15000: Epsilon = 0.0010
#
# Episode 14966/15000: Total reward = 7399
# Episode 14966/15000: Epsilon = 0.0010
#
# Episode 14967/15000: Total reward = 9800
# Episode 14967/15000: Epsilon = 0.0010
#
# Episode 14968/15000: Total reward = -51
# Episode 14968/15000: Epsilon = 0.0010
#
# Episode 14969/15000: Total reward = 9749
# Episode 14969/15000: Epsilon = 0.0010
#
# Episode 14970/15000: Total reward = -51
# Episode 14970/15000: Epsilon = 0.0010
#
# Episode 14971/15000: Total reward = 9749
# Episode 14971/15000: Epsilon = 0.0010
#
# Episode 14972/15000: Total reward = 0
# Episode 14972/15000: Epsilon = 0.0010
#
# Episode 14973/15000: Total reward = 9749
# Episode 14973/15000: Epsilon = 0.0010
#
# Episode 14974/15000: Total reward = 0
# Episode 14974/15000: Epsilon = 0.0010
#
# Episode 14975/15000: Total reward = -51
# Episode 14975/15000: Epsilon = 0.0010
#
# Episode 14976/15000: Total reward = 9647
# Episode 14976/15000: Epsilon = 0.0010
#
# Episode 14977/15000: Total reward = 0
# Episode 14977/15000: Epsilon = 0.0010
#
# Episode 14978/15000: Total reward = 9800
# Episode 14978/15000: Epsilon = 0.0010
#
# Episode 14979/15000: Total reward = 100
# Episode 14979/15000: Epsilon = 0.0010
#
# Episode 14980/15000: Total reward = 0
# Episode 14980/15000: Epsilon = 0.0010
#
# Episode 14981/15000: Total reward = 9647
# Episode 14981/15000: Epsilon = 0.0010
#
# Episode 14982/15000: Total reward = -51
# Episode 14982/15000: Epsilon = 0.0010
#
# Episode 14983/15000: Total reward = 100
# Episode 14983/15000: Epsilon = 0.0010
#
# Episode 14984/15000: Total reward = 9596
# Episode 14984/15000: Epsilon = 0.0010
#
# Episode 14985/15000: Total reward = 100
# Episode 14985/15000: Epsilon = 0.0010
#
# Episode 14986/15000: Total reward = 0
# Episode 14986/15000: Epsilon = 0.0010
#
# Episode 14987/15000: Total reward = 9800
# Episode 14987/15000: Epsilon = 0.0010
#
# Episode 14988/15000: Total reward = 0
# Episode 14988/15000: Epsilon = 0.0010
#
# Episode 14989/15000: Total reward = 9800
# Episode 14989/15000: Epsilon = 0.0010
#
# Episode 14990/15000: Total reward = 0
# Episode 14990/15000: Epsilon = 0.0010
#
# Episode 14991/15000: Total reward = 0
# Episode 14991/15000: Epsilon = 0.0010
#
# Episode 14992/15000: Total reward = 8933
# Episode 14992/15000: Epsilon = 0.0010
#
# Episode 14993/15000: Total reward = 149
# Episode 14993/15000: Epsilon = 0.0010
#
# Episode 14994/15000: Total reward = 9800
# Episode 14994/15000: Epsilon = 0.0010
#
# Episode 14995/15000: Total reward = 100
# Episode 14995/15000: Epsilon = 0.0010
#
# Episode 14996/15000: Total reward = 9545
# Episode 14996/15000: Epsilon = 0.0010
#
# Episode 14997/15000: Total reward = -100
# Episode 14997/15000: Epsilon = 0.0010
#
# Episode 14998/15000: Total reward = 9800
# Episode 14998/15000: Epsilon = 0.0010
#
# Episode 14999/15000: Total reward = 9800
# Episode 14999/15000: Epsilon = 0.0010

# %%
import matplotlib.pyplot as plt

# Adjust the size of the figure (width=12, height=7)
plt.figure(figsize=(12, 7))

# Graph accumulated rewards per episode
plt.plot(rewards_per_episode)
plt.xlabel('Episodes')
plt.ylabel('Accumulated reward')
plt.title('Accumulated rewards per episode')
plt.grid(True)  # Add a grid for clarity
plt.show()

# %% [markdown]
# ---
#
# **RL** agent evaluation.
#
# ---

# %%
import numpy as np

num_test_episodes = 200
test_rewards = []
cpu_usage_final_per_test_episode = []
ram_usage_final_per_test_episode = []

for episode in range(num_test_episodes):
    state = tuple(env.reset())
    total_reward = 0
    done = False

    while not done:
        action = np.argmax(Q[state])
        next_state, reward, done, _ = env.step(action)
        total_reward += reward
        state = tuple(next_state)

    test_rewards.append(total_reward)
    cpu_usage_final_per_test_episode.append(env.num_CPU)  # Record the number of cores used at the end of the episode
    ram_usage_final_per_test_episode.append(env.num_RAM)  # Record the number of gigs of RAM used at the end of the episode

avg_test_reward = np.mean(test_rewards)
print(f'Average reward in {num_test_episodes} test episodes: {avg_test_reward}')
# Out:
# Average reward in 200 test episodes: 5716.755

# %%
# Graph CPU usage at the end of each test episode
plt.figure(figsize=(15, 6))
plt.plot(cpu_usage_final_per_test_episode, label='CPU cores used')
plt.title('CPU cores used at the end of each test episode')
plt.xlabel('Test episode')
plt.ylabel('CPU cores')
plt.legend()
plt.grid(True)
plt.savefig('cpu_usage_final_per_test_episode.png')
plt.show()

# %%
# Graph RAM usage at the end of each test episode
plt.figure(figsize=(15, 6))
plt.plot(ram_usage_final_per_test_episode, label='Gigs of RAM used', color='orange')
plt.title('Gigs of RAM used at the end of each test episode')
plt.xlabel('Test episode')
plt.ylabel('Gigs of RAM')
plt.legend()
plt.grid(True)
plt.savefig('ram_usage_final_per_test_episode.png')
plt.show()
