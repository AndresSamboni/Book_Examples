# %% [markdown]
# <a href="https://colab.research.google.com/github/AndresSamboni/Book_Examples/blob/main/Example_2_DQN_Agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <FONT COLOR='darkgreen'>***EXAMPLE 2 – DQN AGENT***<FONT/>
#
# ---
#
# Building the custom environment
#
# ---

# %%
import gym
from gym import spaces
import numpy as np
from random import randint

# CLASS FOR CUSTOM ENVIRONMENT
class VNFEnvironment(gym.Env):
    # CONSTRUCTOR
    def __init__(self, num_CPU=8, num_RAM=12):
        super(VNFEnvironment, self).__init__()
        self.current_step = 0  # INITIATION OF THE FIRST STEP
        self.max_step = 100  # MAXIMUM NUMBER OF STEPS

        # I CALCULATE 10% OF THE PARAMETERS
        self.cpu_10 = (num_CPU * 10) // 100
        self.ram_10 = (num_RAM * 10) // 100
        if (self.cpu_10 == 0):
          self.cpu_10 = 1
        if (self.ram_10 == 0):
          self.ram_10 = 1

        # I SET THE MINIMUM STARTUP VALUES
        self.min_CPU_init = ((num_CPU * 10) // 100) + 1
        self.min_RAM_init = ((num_RAM * 10) // 100) + 1

        # I SET THE MAXIMUM VALUES AND THE MAXIMUM START VALUES
        self.max_CPU = num_CPU
        self.max_RAM = num_RAM
        self.max_CPU_init = ((num_CPU * 80) // 100) + 1
        self.max_RAM_init = ((num_RAM * 80) // 100) + 1

        # I SET THE INITIAL VALUES
        self.num_CPU = randint(self.min_CPU_init, self.max_CPU_init)  # NUMBER OF INITIAL CPU CORE(S)
        self.num_RAM = randint(self.min_RAM_init, self.max_RAM_init)  # AMOUNT OF INITIAL GB OF RAM

        # I IDENTIFY THE SPACE OF STATES
        self.state_size = 7  # ACTIONS: 0. KEEP BOTH. 1. INCREASE BOTH. 2. DECREASE BOTH.
                            # ACTIONS: 3. MAINTAIN RAM AND INCREASE CPU 4. MAINTAIN RAM AND DECREASE CPU.
                            # ACTIONS: 5. MAINTAIN CPU AND INCREASE RAM. 6. MAINTAIN CPU AND DECREASE RAM.
        self.action_space = spaces.Discrete(self.state_size)

        # DEFINE THE OBSERVATION SPACE
        self.observation_space = spaces.Box(
            low=np.array([0, 0]),
            high=np.array([self.max_CPU, self.max_RAM]),
            dtype=np.int32
        )

        # CREATION OF CPU AND RAM USAGE DICTIONARIES
        self.use_CPU = {
            10: (num_CPU * 10) // 100,
            20: (num_CPU * 20) // 100,
            30: (num_CPU * 30) // 100,
            40: (num_CPU * 40) // 100,
            50: (num_CPU * 50) // 100,
            60: (num_CPU * 60) // 100,
            70: (num_CPU * 70) // 100,
            80: (num_CPU * 80) // 100,
            90: (num_CPU * 90) // 100,
            100: num_CPU
        }
        self.use_RAM = {
            10: (num_RAM * 10) // 100,
            20: (num_RAM * 20) // 100,
            30: (num_RAM * 30) // 100,
            40: (num_RAM * 40) // 100,
            50: (num_RAM * 50) // 100,
            60: (num_RAM * 60) // 100,
            70: (num_RAM * 70) // 100,
            80: (num_RAM * 80) // 100,
            90: (num_RAM * 90) // 100,
            100: num_RAM
        }

        # INITIALIZE ACCUMULATED REWARDS
        self.total_reward = 0
        self.reward_CPU = 0
        self.reward_RAM = 0

    # RESET FUNCTION
    def reset(self):
        self.current_step = 0  # INITIATION OF THE FIRST STEP
        self.num_CPU = randint(self.min_CPU_init, self.max_CPU_init)  # NUMBER OF INITIAL CPU CORE(S)
        self.num_RAM = randint(self.min_RAM_init, self.max_RAM_init)  # AMOUNT OF INITIAL GB OF RAM
        # RESET REWARD VALUES
        self.total_reward = 0
        self.reward_CPU = 0
        self.reward_RAM = 0
        return self._get_state()

    def _get_state(self):
        return np.array([self.num_CPU, self.num_RAM])

    # FUNCTION FOR STEP ACTIONS
    def step(self, action):
        self.current_step += 1

        # REACTIONS TO THE AGENT'S ACTIONS
        if action == 0: #0. KEEP BOTH
            pass
        elif action == 1: #1. INCREASE BOTH
            self.num_CPU = min(self.num_CPU + self.cpu_10, self.max_CPU)
            self.num_RAM = min(self.num_RAM + self.ram_10, self.max_RAM)
        elif action == 2: #2. DECREASE BOTH
            self.num_CPU = max(self.num_CPU - self.cpu_10, 0)
            self.num_RAM = max(self.num_RAM - self.ram_10, 0)
        elif action == 3: #3. KEEP RAM AND BOOST CPU
            self.num_CPU = min(self.num_CPU + self.cpu_10, self.max_CPU)
        elif action == 4: #4. KEEP RAM AND DECREASE CPU
            self.num_CPU = max(self.num_CPU - self.cpu_10, 0)
        elif action == 5: #5. MAINTAIN CPU AND INCREASE RAM
            self.num_RAM = min(self.num_RAM + self.ram_10, self.max_RAM)
        elif action == 6: #6. KEEP CPU AND DECREASE RAM
            self.num_RAM = max(self.num_RAM - self.ram_10, 0)

        # REWARD CALCULATION
        reward, cpu_reward, ram_reward = self._calculate_reward()

        # UPDATE ACCUMULATED REWARDS
        self.total_reward += reward
        self.reward_CPU = cpu_reward
        self.reward_RAM = ram_reward

        # CHECK IF I FINISHED THE EPISODE
        done = self._check_done()

        # GET CURRENT STATUS
        state = self._get_state()

        return state, reward, done, {}

    # FUNCTION FOR REWARD CALCULATION
    def _calculate_reward(self):
        cpu_reward = 0
        ram_reward = 0

       # I CALCULATE THE REWARD FOR THE CPU
        if self.num_CPU <= self.use_CPU[10] or self.num_CPU >= self.use_CPU[80]:
            cpu_reward = -50
        elif self.use_CPU[10] < self.num_CPU < self.use_CPU[70]:
            cpu_reward = -1
        elif self.use_CPU[70] < self.num_CPU < self.use_CPU[80]:
            cpu_reward = -1
        elif self.num_CPU == self.use_CPU[70]:
            cpu_reward = 50

        # I CALCULATE THE RECOMPENSATION FOR THE RAM
        if self.num_RAM <= self.use_RAM[10] or self.num_RAM >= self.use_RAM[80]:
            ram_reward = -50
        elif self.use_RAM[10] < self.num_RAM < self.use_RAM[70]:
            ram_reward = -1
        elif self.use_RAM[70] < self.num_RAM < self.use_RAM[80]:
            ram_reward = -1
        elif self.num_RAM == self.use_RAM[70]:
            ram_reward = 50

        total_reward = cpu_reward + ram_reward
        return total_reward, cpu_reward, ram_reward

    # FUNCTION TO CHECK IF THE EPISODE ENDS
    def _check_done(self):
        if self.current_step >= self.max_step:
            return True
        if self.reward_CPU <= -50:
            return True
        if self.reward_RAM <= -50:
            return True
        if self.reward_CPU <= -50 and self.reward_RAM <= -50:
            return True
        if self.reward_CPU == 50 and self.reward_RAM == 50:
            return True
        return False

# %% [markdown]
# ---
#
# Deep Reinforcement Leaarning **( DRL )** agent.
#
# ---

# %%
import random
import tensorflow as tf
import numpy as np
from tensorflow.keras import layers, models
from collections import deque

# CREATION OF THE DQNAgent CLASS
class DQNAgent:
  # CONSTRUCTOR
  def __init__(self, state_size, action_size):
    # PARAMS INITIALIZE
    self.state_size = state_size
    self.action_size = action_size

    # MEMORY SIZE
    self.memory = deque(maxlen=5000)

    # AGENT PARAMETERS
    self.gamma = 0.95
    self.epsilon = 1.0
    self.epsilon_min = 0.01
    self.epsilon_decay = 0.995
    self.learning_rate = 0.001

    # CREATE MODELS TO TRAIN WITH NN
    self.model = self._build_model()
    self.target_model = self._build_model()
    self.update_target_model()

  # BUILD THE NN MODEL
  def _build_model(self):
    # CREATION OF THE NN
    model = models.Sequential()
    # INPUT LAYER BY THE SPACE STATES IN THE ENVIRONMENT
    model.add(layers.Input(shape=(self.state_size,)))
    # HIDDEN LAYERS FULLY CONNECTED
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(64, activation='relu'))
    # OUTPUT LAYER BY THE SPACE ACTIONS IN THE ENVIRONMENT <-- OBTAIN Q-VALUES
    model.add(layers.Dense(self.action_size))
    # MODEL CONFIGURATIONS
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=self.learning_rate), loss='mean_squared_error')
    return model

  # UPDATE TARGET MODEL
  def update_target_model(self):
    # UPDATING LEARNED WEIGHTS FOR MORE STABLE PREDICTIONS
    self.target_model.set_weights(self.model.get_weights())

  # REMEMBER FUNCTION
  def remember(self, state, action, reward, next_state, done):
    # SAVE EXPERIENCES IN MEMORY
    self.memory.append((state, action, reward, next_state, done))

  # SELECTED ACTIONS FUNCTION
  def act(self, state):
    # STOCK SELECTION BASED ON THE epsilon-greedy POLICY
    if np.random.rand() <= self.epsilon:
      return random.randrange(self.action_size) # EXPLORATION
    else:
      act_values = self.model.predict(state, verbose=0) # EXPLOTATION
      return np.argmax(act_values[0])

  # REPLAY FUNCTION
  def replay(self, batch_size):
    # SAMPLE BATCH
    minibatch = random.sample(self.memory, batch_size)
    # OBTAIN THE PARAMETERS OF THE SAMPLE BATCH
    states = np.vstack([x[0] for x in minibatch])
    actions = np.array([x[1] for x in minibatch])
    rewards = np.array([x[2] for x in minibatch])
    next_states = np.vstack([x[3] for x in minibatch])
    dones = np.array([x[4] for x in minibatch])
    # PREDICT THE TARGETS AND NEXT TARGETS
    targets = self.model.predict(states, verbose=0)
    target_next = self.target_model.predict(next_states, verbose=0)
    # TRAIN THE NN MODEL WITH THE LEARNED Q-VALUES
    for i in range(batch_size):
      if dones[i]:
        targets[i][actions[i]] = rewards[i]
      else:
        targets[i][actions[i]] = rewards[i] + self.gamma * np.amax(target_next[i])
    self.model.fit(states, targets, epochs=1, verbose=0)

  # UPDATE EPSILON FUNCTION
  def update_epsilon(self):
    if self.epsilon > self.epsilon_min:
      self.epsilon *= self.epsilon_decay

# %% [markdown]
# ---
#
# Deep Reinforcement Learning **( DRL )** agent training.
#
# ---

# %%
# ENVIRONMENT INITIALIZE
env = VNFEnvironment()
# GET SCENCIAL PARAMETERS OF THE ENVIRONMENT
state_size = env.observation_space.shape[0]
action_size = env.action_space.n
# AGENT INITIALIZE
agent = DQNAgent(state_size, action_size)
# TRAINING PARAMETERS
batch_size = 64
episodes = 1000
# LIST FOR ACCUMULATED REWARD
rewards_per_episode = []
# TRAINING LOOP
for e in range(episodes):
  # RESET PARAMETERS PER EPISODE
  state = env.reset()
  state = np.reshape(state, [1, state_size])
  total_reward = 0
  done = False
  # FINALIZATION EPISODE LOOP
  while not done:
    # SELECT ACTION
    action = agent.act(state)
    # EXECUTE ACTION
    next_state, reward, done, _ = env.step(action)
    # SAVE REWARD
    total_reward += reward
    # UPDATE NEXT STATE
    next_state = np.reshape(next_state, [1, state_size])
    # SAVE EXPERIENCE IN MEMORY
    agent.remember(state, action, reward, next_state, done)
    # UPDATE THE CURRENT STATE
    state = next_state
    # CHECK IF THE EPISODE IS FINISHED
    if done:
      # UPDATE THE TARGET MODEL
      agent.update_target_model()
      print(f'\nEpisode {e}/{episodes}: Total reward = {total_reward}\nEpisode {e}/{episodes}: Epsilon = {agent.epsilon:.4f}')
      # SAVE REWARD PER EPISODE
      rewards_per_episode.append(total_reward)
      break
    # TRAIN THE NN MODEL OF THE AGENT
    if len(agent.memory) > batch_size:
      agent.replay(batch_size)
  # UPDATE EPSILON VALUE PER EPISODE
  agent.update_epsilon()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Episode 0/1000: Total reward = -100
# Episode 0/1000: Epsilon = 1.0000
#
# Episode 1/1000: Total reward = -118
# Episode 1/1000: Epsilon = 0.9950
#
# Episode 2/1000: Total reward = 0
# Episode 2/1000: Epsilon = 0.9900
#
# Episode 3/1000: Total reward = -51
# Episode 3/1000: Epsilon = 0.9851
#
# Episode 4/1000: Total reward = -51
# Episode 4/1000: Epsilon = 0.9801
#
# Episode 5/1000: Total reward = 47
# Episode 5/1000: Epsilon = 0.9752
#
# Episode 6/1000: Total reward = -51
# Episode 6/1000: Epsilon = 0.9704
#
# Episode 7/1000: Total reward = -100
# Episode 7/1000: Epsilon = 0.9655
#
# Episode 8/1000: Total reward = -51
# Episode 8/1000: Epsilon = 0.9607
#
# Episode 9/1000: Total reward = -100
# Episode 9/1000: Epsilon = 0.9559
#
# Episode 10/1000: Total reward = -119
# Episode 10/1000: Epsilon = 0.9511
#
# Episode 11/1000: Total reward = -79
# Episode 11/1000: Epsilon = 0.9464
#
# Episode 12/1000: Total reward = -2
# Episode 12/1000: Epsilon = 0.9416
#
# Episode 13/1000: Total reward = 0
# Episode 13/1000: Epsilon = 0.9369
#
# Episode 14/1000: Total reward = -6
# Episode 14/1000: Epsilon = 0.9322
#
# Episode 15/1000: Total reward = -51
# Episode 15/1000: Epsilon = 0.9276
#
# Episode 16/1000: Total reward = -6
# Episode 16/1000: Epsilon = 0.9229
#
# Episode 17/1000: Total reward = -100
# Episode 17/1000: Epsilon = 0.9183
#
# Episode 18/1000: Total reward = -63
# Episode 18/1000: Epsilon = 0.9137
#
# Episode 19/1000: Total reward = -51
# Episode 19/1000: Epsilon = 0.9092
#
# Episode 20/1000: Total reward = -51
# Episode 20/1000: Epsilon = 0.9046
#
# Episode 21/1000: Total reward = -51
# Episode 21/1000: Epsilon = 0.9001
#
# Episode 22/1000: Total reward = -100
# Episode 22/1000: Epsilon = 0.8956
#
# Episode 23/1000: Total reward = -53
# Episode 23/1000: Epsilon = 0.8911
#
# Episode 24/1000: Total reward = -4
# Episode 24/1000: Epsilon = 0.8867
#
# Episode 25/1000: Total reward = -51
# Episode 25/1000: Epsilon = 0.8822
#
# Episode 26/1000: Total reward = -2
# Episode 26/1000: Epsilon = 0.8778
#
# Episode 27/1000: Total reward = 45
# Episode 27/1000: Epsilon = 0.8734
#
# Episode 28/1000: Total reward = 96
# Episode 28/1000: Epsilon = 0.8691
#
# Episode 29/1000: Total reward = -51
# Episode 29/1000: Epsilon = 0.8647
#
# Episode 30/1000: Total reward = 0
# Episode 30/1000: Epsilon = 0.8604
#
# Episode 31/1000: Total reward = 0
# Episode 31/1000: Epsilon = 0.8561
#
# Episode 32/1000: Total reward = -51
# Episode 32/1000: Epsilon = 0.8518
#
# Episode 33/1000: Total reward = -8
# Episode 33/1000: Epsilon = 0.8475
#
# Episode 34/1000: Total reward = 0
# Episode 34/1000: Epsilon = 0.8433
#
# Episode 35/1000: Total reward = -4
# Episode 35/1000: Epsilon = 0.8391
#
# Episode 36/1000: Total reward = -61
# Episode 36/1000: Epsilon = 0.8349
#
# Episode 37/1000: Total reward = 80
# Episode 37/1000: Epsilon = 0.8307
#
# Episode 38/1000: Total reward = -51
# Episode 38/1000: Epsilon = 0.8266
#
# Episode 39/1000: Total reward = -51
# Episode 39/1000: Epsilon = 0.8224
#
# Episode 40/1000: Total reward = 145
# Episode 40/1000: Epsilon = 0.8183
#
# Episode 41/1000: Total reward = -4
# Episode 41/1000: Epsilon = 0.8142
#
# Episode 42/1000: Total reward = 0
# Episode 42/1000: Epsilon = 0.8102
#
# Episode 43/1000: Total reward = -51
# Episode 43/1000: Epsilon = 0.8061
#
# Episode 44/1000: Total reward = -2
# Episode 44/1000: Epsilon = 0.8021
#
# Episode 45/1000: Total reward = -51
# Episode 45/1000: Epsilon = 0.7981
#
# Episode 46/1000: Total reward = -2
# Episode 46/1000: Epsilon = 0.7941
#
# Episode 47/1000: Total reward = -51
# Episode 47/1000: Epsilon = 0.7901
#
# Episode 48/1000: Total reward = -51
# Episode 48/1000: Epsilon = 0.7862
#
# Episode 49/1000: Total reward = 147
# Episode 49/1000: Epsilon = 0.7822
#
# Episode 50/1000: Total reward = -73
# Episode 50/1000: Epsilon = 0.7783
#
# Episode 51/1000: Total reward = 50
# Episode 51/1000: Epsilon = 0.7744
#
# Episode 52/1000: Total reward = -51
# Episode 52/1000: Epsilon = 0.7705
#
# Episode 53/1000: Total reward = 38
# Episode 53/1000: Epsilon = 0.7667
#
# Episode 54/1000: Total reward = -51
# Episode 54/1000: Epsilon = 0.7629
#
# Episode 55/1000: Total reward = 0
# Episode 55/1000: Epsilon = 0.7590
#
# Episode 56/1000: Total reward = 94
# Episode 56/1000: Epsilon = 0.7553
#
# Episode 57/1000: Total reward = -51
# Episode 57/1000: Epsilon = 0.7515
#
# Episode 58/1000: Total reward = 229
# Episode 58/1000: Epsilon = 0.7477
#
# Episode 59/1000: Total reward = 239
# Episode 59/1000: Epsilon = 0.7440
#
# Episode 60/1000: Total reward = 560
# Episode 60/1000: Epsilon = 0.7403
#
# Episode 61/1000: Total reward = -100
# Episode 61/1000: Epsilon = 0.7366
#
# Episode 62/1000: Total reward = -51
# Episode 62/1000: Epsilon = 0.7329
#
# Episode 63/1000: Total reward = 41
# Episode 63/1000: Epsilon = 0.7292
#
# Episode 64/1000: Total reward = -51
# Episode 64/1000: Epsilon = 0.7256
#
# Episode 65/1000: Total reward = -100
# Episode 65/1000: Epsilon = 0.7219
#
# Episode 66/1000: Total reward = 47
# Episode 66/1000: Epsilon = 0.7183
#
# Episode 67/1000: Total reward = -57
# Episode 67/1000: Epsilon = 0.7147
#
# Episode 68/1000: Total reward = -51
# Episode 68/1000: Epsilon = 0.7112
#
# Episode 69/1000: Total reward = 0
# Episode 69/1000: Epsilon = 0.7076
#
# Episode 70/1000: Total reward = -8
# Episode 70/1000: Epsilon = 0.7041
#
# Episode 71/1000: Total reward = -51
# Episode 71/1000: Epsilon = 0.7005
#
# Episode 72/1000: Total reward = -53
# Episode 72/1000: Epsilon = 0.6970
#
# Episode 73/1000: Total reward = -4
# Episode 73/1000: Epsilon = 0.6936
#
# Episode 74/1000: Total reward = -51
# Episode 74/1000: Epsilon = 0.6901
#
# Episode 75/1000: Total reward = -51
# Episode 75/1000: Epsilon = 0.6866
#
# Episode 76/1000: Total reward = 270
# Episode 76/1000: Epsilon = 0.6832
#
# Episode 77/1000: Total reward = 19
# Episode 77/1000: Epsilon = 0.6798
#
# Episode 78/1000: Total reward = -100
# Episode 78/1000: Epsilon = 0.6764
#
# Episode 79/1000: Total reward = 100
# Episode 79/1000: Epsilon = 0.6730
#
# Episode 80/1000: Total reward = 227
# Episode 80/1000: Epsilon = 0.6696
#
# Episode 81/1000: Total reward = -55
# Episode 81/1000: Epsilon = 0.6663
#
# Episode 82/1000: Total reward = -2
# Episode 82/1000: Epsilon = 0.6630
#
# Episode 83/1000: Total reward = -51
# Episode 83/1000: Epsilon = 0.6597
#
# Episode 84/1000: Total reward = -51
# Episode 84/1000: Epsilon = 0.6564
#
# Episode 85/1000: Total reward = -20
# Episode 85/1000: Epsilon = 0.6531
#
# Episode 86/1000: Total reward = -2
# Episode 86/1000: Epsilon = 0.6498
#
# Episode 87/1000: Total reward = -51
# Episode 87/1000: Epsilon = 0.6466
#
# Episode 88/1000: Total reward = -51
# Episode 88/1000: Epsilon = 0.6433
#
# Episode 89/1000: Total reward = -100
# Episode 89/1000: Epsilon = 0.6401
#
# Episode 90/1000: Total reward = -30
# Episode 90/1000: Epsilon = 0.6369
#
# Episode 91/1000: Total reward = -87
# Episode 91/1000: Epsilon = 0.6337
#
# Episode 92/1000: Total reward = -51
# Episode 92/1000: Epsilon = 0.6306
#
# Episode 93/1000: Total reward = 90
# Episode 93/1000: Epsilon = 0.6274
#
# Episode 94/1000: Total reward = -100
# Episode 94/1000: Epsilon = 0.6243
#
# Episode 95/1000: Total reward = -51
# Episode 95/1000: Epsilon = 0.6211
#
# Episode 96/1000: Total reward = -51
# Episode 96/1000: Epsilon = 0.6180
#
# Episode 97/1000: Total reward = -51
# Episode 97/1000: Epsilon = 0.6149
#
# Episode 98/1000: Total reward = 444
# Episode 98/1000: Epsilon = 0.6119
#
# Episode 99/1000: Total reward = -51
# Episode 99/1000: Epsilon = 0.6088
#
# Episode 100/1000: Total reward = -18
# Episode 100/1000: Epsilon = 0.6058
#
# Episode 101/1000: Total reward = -100
# Episode 101/1000: Epsilon = 0.6027
#
# Episode 102/1000: Total reward = -189
# Episode 102/1000: Epsilon = 0.5997
#
# Episode 103/1000: Total reward = 147
# Episode 103/1000: Epsilon = 0.5967
#
# Episode 104/1000: Total reward = 235
# Episode 104/1000: Epsilon = 0.5937
#
# Episode 105/1000: Total reward = -51
# Episode 105/1000: Epsilon = 0.5908
#
# Episode 106/1000: Total reward = 0
# Episode 106/1000: Epsilon = 0.5878
#
# Episode 107/1000: Total reward = -51
# Episode 107/1000: Epsilon = 0.5849
#
# Episode 108/1000: Total reward = -51
# Episode 108/1000: Epsilon = 0.5820
#
# Episode 109/1000: Total reward = -51
# Episode 109/1000: Epsilon = 0.5790
#
# Episode 110/1000: Total reward = 286
# Episode 110/1000: Epsilon = 0.5762
#
# Episode 111/1000: Total reward = -51
# Episode 111/1000: Epsilon = 0.5733
#
# Episode 112/1000: Total reward = -89
# Episode 112/1000: Epsilon = 0.5704
#
# Episode 113/1000: Total reward = -100
# Episode 113/1000: Epsilon = 0.5676
#
# Episode 114/1000: Total reward = -51
# Episode 114/1000: Epsilon = 0.5647
#
# Episode 115/1000: Total reward = 145
# Episode 115/1000: Epsilon = 0.5619
#
# Episode 116/1000: Total reward = -51
# Episode 116/1000: Epsilon = 0.5591
#
# Episode 117/1000: Total reward = 0
# Episode 117/1000: Epsilon = 0.5563
#
# Episode 118/1000: Total reward = 98
# Episode 118/1000: Epsilon = 0.5535
#
# Episode 119/1000: Total reward = -67
# Episode 119/1000: Epsilon = 0.5507
#
# Episode 120/1000: Total reward = 135
# Episode 120/1000: Epsilon = 0.5480
#
# Episode 121/1000: Total reward = -51
# Episode 121/1000: Epsilon = 0.5452
#
# Episode 122/1000: Total reward = 145
# Episode 122/1000: Epsilon = 0.5425
#
# Episode 123/1000: Total reward = -100
# Episode 123/1000: Epsilon = 0.5398
#
# Episode 124/1000: Total reward = -51
# Episode 124/1000: Epsilon = 0.5371
#
# Episode 125/1000: Total reward = 303
# Episode 125/1000: Epsilon = 0.5344
#
# Episode 126/1000: Total reward = -2
# Episode 126/1000: Epsilon = 0.5318
#
# Episode 127/1000: Total reward = -51
# Episode 127/1000: Epsilon = 0.5291
#
# Episode 128/1000: Total reward = -51
# Episode 128/1000: Epsilon = 0.5264
#
# Episode 129/1000: Total reward = 374
# Episode 129/1000: Epsilon = 0.5238
#
# Episode 130/1000: Total reward = 363
# Episode 130/1000: Epsilon = 0.5212
#
# Episode 131/1000: Total reward = -51
# Episode 131/1000: Epsilon = 0.5186
#
# Episode 132/1000: Total reward = -51
# Episode 132/1000: Epsilon = 0.5160
#
# Episode 133/1000: Total reward = -51
# Episode 133/1000: Epsilon = 0.5134
#
# Episode 134/1000: Total reward = -51
# Episode 134/1000: Epsilon = 0.5108
#
# Episode 135/1000: Total reward = 353
# Episode 135/1000: Epsilon = 0.5083
#
# Episode 136/1000: Total reward = 437
# Episode 136/1000: Epsilon = 0.5058
#
# Episode 137/1000: Total reward = 354
# Episode 137/1000: Epsilon = 0.5032
#
# Episode 138/1000: Total reward = -51
# Episode 138/1000: Epsilon = 0.5007
#
# Episode 139/1000: Total reward = 501
# Episode 139/1000: Epsilon = 0.4982
#
# Episode 140/1000: Total reward = -116
# Episode 140/1000: Epsilon = 0.4957
#
# Episode 141/1000: Total reward = -2
# Episode 141/1000: Epsilon = 0.4932
#
# Episode 142/1000: Total reward = -51
# Episode 142/1000: Epsilon = 0.4908
#
# Episode 143/1000: Total reward = 100
# Episode 143/1000: Epsilon = 0.4883
#
# Episode 144/1000: Total reward = 0
# Episode 144/1000: Epsilon = 0.4859
#
# Episode 145/1000: Total reward = 29
# Episode 145/1000: Epsilon = 0.4834
#
# Episode 146/1000: Total reward = -51
# Episode 146/1000: Epsilon = 0.4810
#
# Episode 147/1000: Total reward = -101
# Episode 147/1000: Epsilon = 0.4786
#
# Episode 148/1000: Total reward = -16
# Episode 148/1000: Epsilon = 0.4762
#
# Episode 149/1000: Total reward = 0
# Episode 149/1000: Epsilon = 0.4738
#
# Episode 150/1000: Total reward = 384
# Episode 150/1000: Epsilon = 0.4715
#
# Episode 151/1000: Total reward = 34
# Episode 151/1000: Epsilon = 0.4691
#
# Episode 152/1000: Total reward = 100
# Episode 152/1000: Epsilon = 0.4668
#
# Episode 153/1000: Total reward = -51
# Episode 153/1000: Epsilon = 0.4644
#
# Episode 154/1000: Total reward = -10
# Episode 154/1000: Epsilon = 0.4621
#
# Episode 155/1000: Total reward = 335
# Episode 155/1000: Epsilon = 0.4598
#
# Episode 156/1000: Total reward = -3
# Episode 156/1000: Epsilon = 0.4575
#
# Episode 157/1000: Total reward = 237
# Episode 157/1000: Epsilon = 0.4552
#
# Episode 158/1000: Total reward = 172
# Episode 158/1000: Epsilon = 0.4529
#
# Episode 159/1000: Total reward = -51
# Episode 159/1000: Epsilon = 0.4507
#
# Episode 160/1000: Total reward = -51
# Episode 160/1000: Epsilon = 0.4484
#
# Episode 161/1000: Total reward = 54
# Episode 161/1000: Epsilon = 0.4462
#
# Episode 162/1000: Total reward = 0
# Episode 162/1000: Epsilon = 0.4440
#
# Episode 163/1000: Total reward = 433
# Episode 163/1000: Epsilon = 0.4417
#
# Episode 164/1000: Total reward = 192
# Episode 164/1000: Epsilon = 0.4395
#
# Episode 165/1000: Total reward = -100
# Episode 165/1000: Epsilon = 0.4373
#
# Episode 166/1000: Total reward = 0
# Episode 166/1000: Epsilon = 0.4351
#
# Episode 167/1000: Total reward = -51
# Episode 167/1000: Epsilon = 0.4330
#
# Episode 168/1000: Total reward = -51
# Episode 168/1000: Epsilon = 0.4308
#
# Episode 169/1000: Total reward = 141
# Episode 169/1000: Epsilon = 0.4286
#
# Episode 170/1000: Total reward = 0
# Episode 170/1000: Epsilon = 0.4265
#
# Episode 171/1000: Total reward = -51
# Episode 171/1000: Epsilon = 0.4244
#
# Episode 172/1000: Total reward = 235
# Episode 172/1000: Epsilon = 0.4223
#
# Episode 173/1000: Total reward = -121
# Episode 173/1000: Epsilon = 0.4201
#
# Episode 174/1000: Total reward = -100
# Episode 174/1000: Epsilon = 0.4180
#
# Episode 175/1000: Total reward = 463
# Episode 175/1000: Epsilon = 0.4159
#
# Episode 176/1000: Total reward = 787
# Episode 176/1000: Epsilon = 0.4139
#
# Episode 177/1000: Total reward = -51
# Episode 177/1000: Epsilon = 0.4118
#
# Episode 178/1000: Total reward = 47
# Episode 178/1000: Epsilon = 0.4097
#
# Episode 179/1000: Total reward = 327
# Episode 179/1000: Epsilon = 0.4077
#
# Episode 180/1000: Total reward = -51
# Episode 180/1000: Epsilon = 0.4057
#
# Episode 181/1000: Total reward = -51
# Episode 181/1000: Epsilon = 0.4036
#
# Episode 182/1000: Total reward = -100
# Episode 182/1000: Epsilon = 0.4016
#
# Episode 183/1000: Total reward = 0
# Episode 183/1000: Epsilon = 0.3996
#
# Episode 184/1000: Total reward = -51
# Episode 184/1000: Epsilon = 0.3976
#
# Episode 185/1000: Total reward = 149
# Episode 185/1000: Epsilon = 0.3956
#
# Episode 186/1000: Total reward = -51
# Episode 186/1000: Epsilon = 0.3936
#
# Episode 187/1000: Total reward = 598
# Episode 187/1000: Epsilon = 0.3917
#
# Episode 188/1000: Total reward = -57
# Episode 188/1000: Epsilon = 0.3897
#
# Episode 189/1000: Total reward = -110
# Episode 189/1000: Epsilon = 0.3878
#
# Episode 190/1000: Total reward = -51
# Episode 190/1000: Epsilon = 0.3858
#
# Episode 191/1000: Total reward = 145
# Episode 191/1000: Epsilon = 0.3839
#
# Episode 192/1000: Total reward = -100
# Episode 192/1000: Epsilon = 0.3820
#
# Episode 193/1000: Total reward = 474
# Episode 193/1000: Epsilon = 0.3801
#
# Episode 194/1000: Total reward = -51
# Episode 194/1000: Epsilon = 0.3782
#
# Episode 195/1000: Total reward = 378
# Episode 195/1000: Epsilon = 0.3763
#
# Episode 196/1000: Total reward = 345
# Episode 196/1000: Epsilon = 0.3744
#
# Episode 197/1000: Total reward = 0
# Episode 197/1000: Epsilon = 0.3725
#
# Episode 198/1000: Total reward = 55
# Episode 198/1000: Epsilon = 0.3707
#
# Episode 199/1000: Total reward = -117
# Episode 199/1000: Epsilon = 0.3688
#
# Episode 200/1000: Total reward = 0
# Episode 200/1000: Epsilon = 0.3670
#
# Episode 201/1000: Total reward = -2
# Episode 201/1000: Epsilon = 0.3651
#
# Episode 202/1000: Total reward = 42
# Episode 202/1000: Epsilon = 0.3633
#
# Episode 203/1000: Total reward = 31
# Episode 203/1000: Epsilon = 0.3615
#
# Episode 204/1000: Total reward = -51
# Episode 204/1000: Epsilon = 0.3597
#
# Episode 205/1000: Total reward = -97
# Episode 205/1000: Epsilon = 0.3579
#
# Episode 206/1000: Total reward = 0
# Episode 206/1000: Epsilon = 0.3561
#
# Episode 207/1000: Total reward = 693
# Episode 207/1000: Epsilon = 0.3543
#
# Episode 208/1000: Total reward = -2
# Episode 208/1000: Epsilon = 0.3525
#
# Episode 209/1000: Total reward = -51
# Episode 209/1000: Epsilon = 0.3508
#
# Episode 210/1000: Total reward = 49
# Episode 210/1000: Epsilon = 0.3490
#
# Episode 211/1000: Total reward = -69
# Episode 211/1000: Epsilon = 0.3473
#
# Episode 212/1000: Total reward = -51
# Episode 212/1000: Epsilon = 0.3455
#
# Episode 213/1000: Total reward = -51
# Episode 213/1000: Epsilon = 0.3438
#
# Episode 214/1000: Total reward = 194
# Episode 214/1000: Epsilon = 0.3421
#
# Episode 215/1000: Total reward = -51
# Episode 215/1000: Epsilon = 0.3404
#
# Episode 216/1000: Total reward = -51
# Episode 216/1000: Epsilon = 0.3387
#
# Episode 217/1000: Total reward = 194
# Episode 217/1000: Epsilon = 0.3370
#
# Episode 218/1000: Total reward = -51
# Episode 218/1000: Epsilon = 0.3353
#
# Episode 219/1000: Total reward = 0
# Episode 219/1000: Epsilon = 0.3336
#
# Episode 220/1000: Total reward = 466
# Episode 220/1000: Epsilon = 0.3320
#
# Episode 221/1000: Total reward = 47
# Episode 221/1000: Epsilon = 0.3303
#
# Episode 222/1000: Total reward = -51
# Episode 222/1000: Epsilon = 0.3286
#
# Episode 223/1000: Total reward = -51
# Episode 223/1000: Epsilon = 0.3270
#
# Episode 224/1000: Total reward = 117
# Episode 224/1000: Epsilon = 0.3254
#
# Episode 225/1000: Total reward = -51
# Episode 225/1000: Epsilon = 0.3237
#
# Episode 226/1000: Total reward = 278
# Episode 226/1000: Epsilon = 0.3221
#
# Episode 227/1000: Total reward = -51
# Episode 227/1000: Epsilon = 0.3205
#
# Episode 228/1000: Total reward = 782
# Episode 228/1000: Epsilon = 0.3189
#
# Episode 229/1000: Total reward = -51
# Episode 229/1000: Epsilon = 0.3173
#
# Episode 230/1000: Total reward = -51
# Episode 230/1000: Epsilon = 0.3157
#
# Episode 231/1000: Total reward = 86
# Episode 231/1000: Epsilon = 0.3141
#
# Episode 232/1000: Total reward = 219
# Episode 232/1000: Epsilon = 0.3126
#
# Episode 233/1000: Total reward = 619
# Episode 233/1000: Epsilon = 0.3110
#
# Episode 234/1000: Total reward = 96
# Episode 234/1000: Epsilon = 0.3095
#
# Episode 235/1000: Total reward = -62
# Episode 235/1000: Epsilon = 0.3079
#
# Episode 236/1000: Total reward = -51
# Episode 236/1000: Epsilon = 0.3064
#
# Episode 237/1000: Total reward = 946
# Episode 237/1000: Epsilon = 0.3048
#
# Episode 238/1000: Total reward = 33
# Episode 238/1000: Epsilon = 0.3033
#
# Episode 239/1000: Total reward = 0
# Episode 239/1000: Epsilon = 0.3018
#
# Episode 240/1000: Total reward = -51
# Episode 240/1000: Epsilon = 0.3003
#
# Episode 241/1000: Total reward = -51
# Episode 241/1000: Epsilon = 0.2988
#
# Episode 242/1000: Total reward = 194
# Episode 242/1000: Epsilon = 0.2973
#
# Episode 243/1000: Total reward = 0
# Episode 243/1000: Epsilon = 0.2958
#
# Episode 244/1000: Total reward = -51
# Episode 244/1000: Epsilon = 0.2943
#
# Episode 245/1000: Total reward = -61
# Episode 245/1000: Epsilon = 0.2929
#
# Episode 246/1000: Total reward = 187
# Episode 246/1000: Epsilon = 0.2914
#
# Episode 247/1000: Total reward = -51
# Episode 247/1000: Epsilon = 0.2899
#
# Episode 248/1000: Total reward = 45
# Episode 248/1000: Epsilon = 0.2885
#
# Episode 249/1000: Total reward = 115
# Episode 249/1000: Epsilon = 0.2870
#
# Episode 250/1000: Total reward = 673
# Episode 250/1000: Epsilon = 0.2856
#
# Episode 251/1000: Total reward = 335
# Episode 251/1000: Epsilon = 0.2842
#
# Episode 252/1000: Total reward = -51
# Episode 252/1000: Epsilon = 0.2828
#
# Episode 253/1000: Total reward = 80
# Episode 253/1000: Epsilon = 0.2813
#
# Episode 254/1000: Total reward = -74
# Episode 254/1000: Epsilon = 0.2799
#
# Episode 255/1000: Total reward = 98
# Episode 255/1000: Epsilon = 0.2785
#
# Episode 256/1000: Total reward = 152
# Episode 256/1000: Epsilon = 0.2771
#
# Episode 257/1000: Total reward = -51
# Episode 257/1000: Epsilon = 0.2758
#
# Episode 258/1000: Total reward = -51
# Episode 258/1000: Epsilon = 0.2744
#
# Episode 259/1000: Total reward = -51
# Episode 259/1000: Epsilon = 0.2730
#
# Episode 260/1000: Total reward = -51
# Episode 260/1000: Epsilon = 0.2716
#
# Episode 261/1000: Total reward = 441
# Episode 261/1000: Epsilon = 0.2703
#
# Episode 262/1000: Total reward = -22
# Episode 262/1000: Epsilon = 0.2689
#
# Episode 263/1000: Total reward = 289
# Episode 263/1000: Epsilon = 0.2676
#
# Episode 264/1000: Total reward = -42
# Episode 264/1000: Epsilon = 0.2663
#
# Episode 265/1000: Total reward = -79
# Episode 265/1000: Epsilon = 0.2649
#
# Episode 266/1000: Total reward = 50
# Episode 266/1000: Epsilon = 0.2636
#
# Episode 267/1000: Total reward = 0
# Episode 267/1000: Epsilon = 0.2623
#
# Episode 268/1000: Total reward = -2
# Episode 268/1000: Epsilon = 0.2610
#
# Episode 269/1000: Total reward = 1021
# Episode 269/1000: Epsilon = 0.2597
#
# Episode 270/1000: Total reward = -2
# Episode 270/1000: Epsilon = 0.2584
#
# Episode 271/1000: Total reward = 445
# Episode 271/1000: Epsilon = 0.2571
#
# Episode 272/1000: Total reward = -15
# Episode 272/1000: Epsilon = 0.2558
#
# Episode 273/1000: Total reward = -51
# Episode 273/1000: Epsilon = 0.2545
#
# Episode 274/1000: Total reward = -51
# Episode 274/1000: Epsilon = 0.2532
#
# Episode 275/1000: Total reward = 221
# Episode 275/1000: Epsilon = 0.2520
#
# Episode 276/1000: Total reward = -51
# Episode 276/1000: Epsilon = 0.2507
#
# Episode 277/1000: Total reward = -51
# Episode 277/1000: Epsilon = 0.2495
#
# Episode 278/1000: Total reward = 758
# Episode 278/1000: Epsilon = 0.2482
#
# Episode 279/1000: Total reward = -51
# Episode 279/1000: Epsilon = 0.2470
#
# Episode 280/1000: Total reward = -89
# Episode 280/1000: Epsilon = 0.2457
#
# Episode 281/1000: Total reward = 39
# Episode 281/1000: Epsilon = 0.2445
#
# Episode 282/1000: Total reward = 0
# Episode 282/1000: Epsilon = 0.2433
#
# Episode 283/1000: Total reward = -51
# Episode 283/1000: Epsilon = 0.2421
#
# Episode 284/1000: Total reward = 0
# Episode 284/1000: Epsilon = 0.2409
#
# Episode 285/1000: Total reward = 84
# Episode 285/1000: Epsilon = 0.2397
#
# Episode 286/1000: Total reward = -51
# Episode 286/1000: Epsilon = 0.2385
#
# Episode 287/1000: Total reward = 436
# Episode 287/1000: Epsilon = 0.2373
#
# Episode 288/1000: Total reward = -51
# Episode 288/1000: Epsilon = 0.2361
#
# Episode 289/1000: Total reward = -51
# Episode 289/1000: Epsilon = 0.2349
#
# Episode 290/1000: Total reward = 742
# Episode 290/1000: Epsilon = 0.2337
#
# Episode 291/1000: Total reward = 517
# Episode 291/1000: Epsilon = 0.2326
#
# Episode 292/1000: Total reward = -51
# Episode 292/1000: Epsilon = 0.2314
#
# Episode 293/1000: Total reward = 1095
# Episode 293/1000: Epsilon = 0.2302
#
# Episode 294/1000: Total reward = 463
# Episode 294/1000: Epsilon = 0.2291
#
# Episode 295/1000: Total reward = -51
# Episode 295/1000: Epsilon = 0.2279
#
# Episode 296/1000: Total reward = -51
# Episode 296/1000: Epsilon = 0.2268
#
# Episode 297/1000: Total reward = 462
# Episode 297/1000: Epsilon = 0.2257
#
# Episode 298/1000: Total reward = -51
# Episode 298/1000: Epsilon = 0.2245
#
# Episode 299/1000: Total reward = 150
# Episode 299/1000: Epsilon = 0.2234
#
# Episode 300/1000: Total reward = 124
# Episode 300/1000: Epsilon = 0.2223
#
# Episode 301/1000: Total reward = 588
# Episode 301/1000: Epsilon = 0.2212
#
# Episode 302/1000: Total reward = 55
# Episode 302/1000: Epsilon = 0.2201
#
# Episode 303/1000: Total reward = -51
# Episode 303/1000: Epsilon = 0.2190
#
# Episode 304/1000: Total reward = -51
# Episode 304/1000: Epsilon = 0.2179
#
# Episode 305/1000: Total reward = 1254
# Episode 305/1000: Epsilon = 0.2168
#
# Episode 306/1000: Total reward = -51
# Episode 306/1000: Epsilon = 0.2157
#
# Episode 307/1000: Total reward = -51
# Episode 307/1000: Epsilon = 0.2146
#
# Episode 308/1000: Total reward = 181
# Episode 308/1000: Epsilon = 0.2136
#
# Episode 309/1000: Total reward = -51
# Episode 309/1000: Epsilon = 0.2125
#
# Episode 310/1000: Total reward = 0
# Episode 310/1000: Epsilon = 0.2114
#
# Episode 311/1000: Total reward = -51
# Episode 311/1000: Epsilon = 0.2104
#
# Episode 312/1000: Total reward = -100
# Episode 312/1000: Epsilon = 0.2093
#
# Episode 313/1000: Total reward = -51
# Episode 313/1000: Epsilon = 0.2083
#
# Episode 314/1000: Total reward = -51
# Episode 314/1000: Epsilon = 0.2072
#
# Episode 315/1000: Total reward = -51
# Episode 315/1000: Epsilon = 0.2062
#
# Episode 316/1000: Total reward = 697
# Episode 316/1000: Epsilon = 0.2052
#
# Episode 317/1000: Total reward = 1687
# Episode 317/1000: Epsilon = 0.2041
#
# Episode 318/1000: Total reward = -51
# Episode 318/1000: Epsilon = 0.2031
#
# Episode 319/1000: Total reward = -51
# Episode 319/1000: Epsilon = 0.2021
#
# Episode 320/1000: Total reward = 375
# Episode 320/1000: Epsilon = 0.2011
#
# Episode 321/1000: Total reward = 747
# Episode 321/1000: Epsilon = 0.2001
#
# Episode 322/1000: Total reward = 2146
# Episode 322/1000: Epsilon = 0.1991
#
# Episode 323/1000: Total reward = 43
# Episode 323/1000: Epsilon = 0.1981
#
# Episode 324/1000: Total reward = 0
# Episode 324/1000: Epsilon = 0.1971
#
# Episode 325/1000: Total reward = 47
# Episode 325/1000: Epsilon = 0.1961
#
# Episode 326/1000: Total reward = -51
# Episode 326/1000: Epsilon = 0.1951
#
# Episode 327/1000: Total reward = 871
# Episode 327/1000: Epsilon = 0.1942
#
# Episode 328/1000: Total reward = -51
# Episode 328/1000: Epsilon = 0.1932
#
# Episode 329/1000: Total reward = 0
# Episode 329/1000: Epsilon = 0.1922
#
# Episode 330/1000: Total reward = 1146
# Episode 330/1000: Epsilon = 0.1913
#
# Episode 331/1000: Total reward = 2115
# Episode 331/1000: Epsilon = 0.1903
#
# Episode 332/1000: Total reward = 168
# Episode 332/1000: Epsilon = 0.1893
#
# Episode 333/1000: Total reward = -39
# Episode 333/1000: Epsilon = 0.1884
#
# Episode 334/1000: Total reward = 0
# Episode 334/1000: Epsilon = 0.1875
#
# Episode 335/1000: Total reward = -51
# Episode 335/1000: Epsilon = 0.1865
#
# Episode 336/1000: Total reward = -51
# Episode 336/1000: Epsilon = 0.1856
#
# Episode 337/1000: Total reward = 903
# Episode 337/1000: Epsilon = 0.1847
#
# Episode 338/1000: Total reward = 586
# Episode 338/1000: Epsilon = 0.1837
#
# Episode 339/1000: Total reward = 0
# Episode 339/1000: Epsilon = 0.1828
#
# Episode 340/1000: Total reward = 454
# Episode 340/1000: Epsilon = 0.1819
#
# Episode 341/1000: Total reward = 1216
# Episode 341/1000: Epsilon = 0.1810
#
# Episode 342/1000: Total reward = 309
# Episode 342/1000: Epsilon = 0.1801
#
# Episode 343/1000: Total reward = 1089
# Episode 343/1000: Epsilon = 0.1792
#
# Episode 344/1000: Total reward = 109
# Episode 344/1000: Epsilon = 0.1783
#
# Episode 345/1000: Total reward = 0
# Episode 345/1000: Epsilon = 0.1774
#
# Episode 346/1000: Total reward = -51
# Episode 346/1000: Epsilon = 0.1765
#
# Episode 347/1000: Total reward = 343
# Episode 347/1000: Epsilon = 0.1756
#
# Episode 348/1000: Total reward = -100
# Episode 348/1000: Epsilon = 0.1748
#
# Episode 349/1000: Total reward = 41
# Episode 349/1000: Epsilon = 0.1739
#
# Episode 350/1000: Total reward = 390
# Episode 350/1000: Epsilon = 0.1730
#
# Episode 351/1000: Total reward = 292
# Episode 351/1000: Epsilon = 0.1721
#
# Episode 352/1000: Total reward = 225
# Episode 352/1000: Epsilon = 0.1713
#
# Episode 353/1000: Total reward = -51
# Episode 353/1000: Epsilon = 0.1704
#
# Episode 354/1000: Total reward = 2044
# Episode 354/1000: Epsilon = 0.1696
#
# Episode 355/1000: Total reward = -51
# Episode 355/1000: Epsilon = 0.1687
#
# Episode 356/1000: Total reward = -61
# Episode 356/1000: Epsilon = 0.1679
#
# Episode 357/1000: Total reward = 1942
# Episode 357/1000: Epsilon = 0.1670
#
# Episode 358/1000: Total reward = -51
# Episode 358/1000: Epsilon = 0.1662
#
# Episode 359/1000: Total reward = -2
# Episode 359/1000: Epsilon = 0.1654
#
# Episode 360/1000: Total reward = 875
# Episode 360/1000: Epsilon = 0.1646
#
# Episode 361/1000: Total reward = 0
# Episode 361/1000: Epsilon = 0.1637
#
# Episode 362/1000: Total reward = -51
# Episode 362/1000: Epsilon = 0.1629
#
# Episode 363/1000: Total reward = -2
# Episode 363/1000: Epsilon = 0.1621
#
# Episode 364/1000: Total reward = 145
# Episode 364/1000: Epsilon = 0.1613
#
# Episode 365/1000: Total reward = -51
# Episode 365/1000: Epsilon = 0.1605
#
# Episode 366/1000: Total reward = -51
# Episode 366/1000: Epsilon = 0.1597
#
# Episode 367/1000: Total reward = -51
# Episode 367/1000: Epsilon = 0.1589
#
# Episode 368/1000: Total reward = 871
# Episode 368/1000: Epsilon = 0.1581
#
# Episode 369/1000: Total reward = 0
# Episode 369/1000: Epsilon = 0.1573
#
# Episode 370/1000: Total reward = -100
# Episode 370/1000: Epsilon = 0.1565
#
# Episode 371/1000: Total reward = 498
# Episode 371/1000: Epsilon = 0.1557
#
# Episode 372/1000: Total reward = 1068
# Episode 372/1000: Epsilon = 0.1549
#
# Episode 373/1000: Total reward = 1756
# Episode 373/1000: Epsilon = 0.1542
#
# Episode 374/1000: Total reward = 1355
# Episode 374/1000: Epsilon = 0.1534
#
# Episode 375/1000: Total reward = 390
# Episode 375/1000: Epsilon = 0.1526
#
# Episode 376/1000: Total reward = 2554
# Episode 376/1000: Epsilon = 0.1519
#
# Episode 377/1000: Total reward = -51
# Episode 377/1000: Epsilon = 0.1511
#
# Episode 378/1000: Total reward = -51
# Episode 378/1000: Epsilon = 0.1504
#
# Episode 379/1000: Total reward = -51
# Episode 379/1000: Epsilon = 0.1496
#
# Episode 380/1000: Total reward = 715
# Episode 380/1000: Epsilon = 0.1489
#
# Episode 381/1000: Total reward = 100
# Episode 381/1000: Epsilon = 0.1481
#
# Episode 382/1000: Total reward = -47
# Episode 382/1000: Epsilon = 0.1474
#
# Episode 383/1000: Total reward = -100
# Episode 383/1000: Epsilon = 0.1466
#
# Episode 384/1000: Total reward = 55
# Episode 384/1000: Epsilon = 0.1459
#
# Episode 385/1000: Total reward = 292
# Episode 385/1000: Epsilon = 0.1452
#
# Episode 386/1000: Total reward = 1541
# Episode 386/1000: Epsilon = 0.1444
#
# Episode 387/1000: Total reward = 245
# Episode 387/1000: Epsilon = 0.1437
#
# Episode 388/1000: Total reward = -51
# Episode 388/1000: Epsilon = 0.1430
#
# Episode 389/1000: Total reward = -51
# Episode 389/1000: Epsilon = 0.1423
#
# Episode 390/1000: Total reward = -100
# Episode 390/1000: Epsilon = 0.1416
#
# Episode 391/1000: Total reward = 399
# Episode 391/1000: Epsilon = 0.1409
#
# Episode 392/1000: Total reward = 145
# Episode 392/1000: Epsilon = 0.1402
#
# Episode 393/1000: Total reward = -51
# Episode 393/1000: Epsilon = 0.1395
#
# Episode 394/1000: Total reward = -51
# Episode 394/1000: Epsilon = 0.1388
#
# Episode 395/1000: Total reward = -51
# Episode 395/1000: Epsilon = 0.1381
#
# Episode 396/1000: Total reward = 1026
# Episode 396/1000: Epsilon = 0.1374
#
# Episode 397/1000: Total reward = 973
# Episode 397/1000: Epsilon = 0.1367
#
# Episode 398/1000: Total reward = 0
# Episode 398/1000: Epsilon = 0.1360
#
# Episode 399/1000: Total reward = 1163
# Episode 399/1000: Epsilon = 0.1353
#
# Episode 400/1000: Total reward = 83
# Episode 400/1000: Epsilon = 0.1347
#
# Episode 401/1000: Total reward = -51
# Episode 401/1000: Epsilon = 0.1340
#
# Episode 402/1000: Total reward = 1521
# Episode 402/1000: Epsilon = 0.1333
#
# Episode 403/1000: Total reward = -51
# Episode 403/1000: Epsilon = 0.1326
#
# Episode 404/1000: Total reward = 0
# Episode 404/1000: Epsilon = 0.1320
#
# Episode 405/1000: Total reward = -51
# Episode 405/1000: Epsilon = 0.1313
#
# Episode 406/1000: Total reward = 68
# Episode 406/1000: Epsilon = 0.1307
#
# Episode 407/1000: Total reward = -51
# Episode 407/1000: Epsilon = 0.1300
#
# Episode 408/1000: Total reward = -51
# Episode 408/1000: Epsilon = 0.1294
#
# Episode 409/1000: Total reward = 1173
# Episode 409/1000: Epsilon = 0.1287
#
# Episode 410/1000: Total reward = 613
# Episode 410/1000: Epsilon = 0.1281
#
# Episode 411/1000: Total reward = 49
# Episode 411/1000: Epsilon = 0.1274
#
# Episode 412/1000: Total reward = 0
# Episode 412/1000: Epsilon = 0.1268
#
# Episode 413/1000: Total reward = 2511
# Episode 413/1000: Epsilon = 0.1262
#
# Episode 414/1000: Total reward = -51
# Episode 414/1000: Epsilon = 0.1255
#
# Episode 415/1000: Total reward = 439
# Episode 415/1000: Epsilon = 0.1249
#
# Episode 416/1000: Total reward = 2044
# Episode 416/1000: Epsilon = 0.1243
#
# Episode 417/1000: Total reward = 2330
# Episode 417/1000: Epsilon = 0.1237
#
# Episode 418/1000: Total reward = 0
# Episode 418/1000: Epsilon = 0.1230
#
# Episode 419/1000: Total reward = 292
# Episode 419/1000: Epsilon = 0.1224
#
# Episode 420/1000: Total reward = 1289
# Episode 420/1000: Epsilon = 0.1218
#
# Episode 421/1000: Total reward = 288
# Episode 421/1000: Epsilon = 0.1212
#
# Episode 422/1000: Total reward = 227
# Episode 422/1000: Epsilon = 0.1206
#
# Episode 423/1000: Total reward = -51
# Episode 423/1000: Epsilon = 0.1200
#
# Episode 424/1000: Total reward = -8
# Episode 424/1000: Epsilon = 0.1194
#
# Episode 425/1000: Total reward = 0
# Episode 425/1000: Epsilon = 0.1188
#
# Episode 426/1000: Total reward = -51
# Episode 426/1000: Epsilon = 0.1182
#
# Episode 427/1000: Total reward = -51
# Episode 427/1000: Epsilon = 0.1176
#
# Episode 428/1000: Total reward = 0
# Episode 428/1000: Epsilon = 0.1170
#
# Episode 429/1000: Total reward = 856
# Episode 429/1000: Epsilon = 0.1164
#
# Episode 430/1000: Total reward = -51
# Episode 430/1000: Epsilon = 0.1159
#
# Episode 431/1000: Total reward = -51
# Episode 431/1000: Epsilon = 0.1153
#
# Episode 432/1000: Total reward = 1074
# Episode 432/1000: Epsilon = 0.1147
#
# Episode 433/1000: Total reward = 92
# Episode 433/1000: Epsilon = 0.1141
#
# Episode 434/1000: Total reward = 831
# Episode 434/1000: Epsilon = 0.1136
#
# Episode 435/1000: Total reward = 1748
# Episode 435/1000: Epsilon = 0.1130
#
# Episode 436/1000: Total reward = 1409
# Episode 436/1000: Epsilon = 0.1124
#
# Episode 437/1000: Total reward = -51
# Episode 437/1000: Epsilon = 0.1119
#
# Episode 438/1000: Total reward = 0
# Episode 438/1000: Epsilon = 0.1113
#
# Episode 439/1000: Total reward = 2416
# Episode 439/1000: Epsilon = 0.1107
#
# Episode 440/1000: Total reward = -100
# Episode 440/1000: Epsilon = 0.1102
#
# Episode 441/1000: Total reward = 4543
# Episode 441/1000: Epsilon = 0.1096
#
# Episode 442/1000: Total reward = 384
# Episode 442/1000: Epsilon = 0.1091
#
# Episode 443/1000: Total reward = -51
# Episode 443/1000: Epsilon = 0.1085
#
# Episode 444/1000: Total reward = -51
# Episode 444/1000: Epsilon = 0.1080
#
# Episode 445/1000: Total reward = -100
# Episode 445/1000: Epsilon = 0.1075
#
# Episode 446/1000: Total reward = 2136
# Episode 446/1000: Epsilon = 0.1069
#
# Episode 447/1000: Total reward = 917
# Episode 447/1000: Epsilon = 0.1064
#
# Episode 448/1000: Total reward = 337
# Episode 448/1000: Epsilon = 0.1059
#
# Episode 449/1000: Total reward = 329
# Episode 449/1000: Epsilon = 0.1053
#
# Episode 450/1000: Total reward = -51
# Episode 450/1000: Epsilon = 0.1048
#
# Episode 451/1000: Total reward = 90
# Episode 451/1000: Epsilon = 0.1043
#
# Episode 452/1000: Total reward = -51
# Episode 452/1000: Epsilon = 0.1038
#
# Episode 453/1000: Total reward = 2683
# Episode 453/1000: Epsilon = 0.1032
#
# Episode 454/1000: Total reward = 4353
# Episode 454/1000: Epsilon = 0.1027
#
# Episode 455/1000: Total reward = 194
# Episode 455/1000: Epsilon = 0.1022
#
# Episode 456/1000: Total reward = -51
# Episode 456/1000: Epsilon = 0.1017
#
# Episode 457/1000: Total reward = 578
# Episode 457/1000: Epsilon = 0.1012
#
# Episode 458/1000: Total reward = -51
# Episode 458/1000: Epsilon = 0.1007
#
# Episode 459/1000: Total reward = 1950
# Episode 459/1000: Epsilon = 0.1002
#
# Episode 460/1000: Total reward = -100
# Episode 460/1000: Epsilon = 0.0997
#
# Episode 461/1000: Total reward = 1168
# Episode 461/1000: Epsilon = 0.0992
#
# Episode 462/1000: Total reward = 294
# Episode 462/1000: Epsilon = 0.0987
#
# Episode 463/1000: Total reward = -51
# Episode 463/1000: Epsilon = 0.0982
#
# Episode 464/1000: Total reward = -51
# Episode 464/1000: Epsilon = 0.0977
#
# Episode 465/1000: Total reward = 727
# Episode 465/1000: Epsilon = 0.0972
#
# Episode 466/1000: Total reward = -51
# Episode 466/1000: Epsilon = 0.0967
#
# Episode 467/1000: Total reward = 0
# Episode 467/1000: Epsilon = 0.0962
#
# Episode 468/1000: Total reward = -51
# Episode 468/1000: Epsilon = 0.0958
#
# Episode 469/1000: Total reward = -100
# Episode 469/1000: Epsilon = 0.0953
#
# Episode 470/1000: Total reward = -51
# Episode 470/1000: Epsilon = 0.0948
#
# Episode 471/1000: Total reward = 2647
# Episode 471/1000: Epsilon = 0.0943
#
# Episode 472/1000: Total reward = -51
# Episode 472/1000: Epsilon = 0.0939
#
# Episode 473/1000: Total reward = -51
# Episode 473/1000: Epsilon = 0.0934
#
# Episode 474/1000: Total reward = -51
# Episode 474/1000: Epsilon = 0.0929
#
# Episode 475/1000: Total reward = -51
# Episode 475/1000: Epsilon = 0.0925
#
# Episode 476/1000: Total reward = -51
# Episode 476/1000: Epsilon = 0.0920
#
# Episode 477/1000: Total reward = 291
# Episode 477/1000: Epsilon = 0.0915
#
# Episode 478/1000: Total reward = -100
# Episode 478/1000: Epsilon = 0.0911
#
# Episode 479/1000: Total reward = 100
# Episode 479/1000: Epsilon = 0.0906
#
# Episode 480/1000: Total reward = 0
# Episode 480/1000: Epsilon = 0.0902
#
# Episode 481/1000: Total reward = 635
# Episode 481/1000: Epsilon = 0.0897
#
# Episode 482/1000: Total reward = -100
# Episode 482/1000: Epsilon = 0.0893
#
# Episode 483/1000: Total reward = 1313
# Episode 483/1000: Epsilon = 0.0888
#
# Episode 484/1000: Total reward = 96
# Episode 484/1000: Epsilon = 0.0884
#
# Episode 485/1000: Total reward = 1321
# Episode 485/1000: Epsilon = 0.0879
#
# Episode 486/1000: Total reward = -51
# Episode 486/1000: Epsilon = 0.0875
#
# Episode 487/1000: Total reward = 638
# Episode 487/1000: Epsilon = 0.0871
#
# Episode 488/1000: Total reward = -51
# Episode 488/1000: Epsilon = 0.0866
#
# Episode 489/1000: Total reward = -51
# Episode 489/1000: Epsilon = 0.0862
#
# Episode 490/1000: Total reward = 3404
# Episode 490/1000: Epsilon = 0.0858
#
# Episode 491/1000: Total reward = 433
# Episode 491/1000: Epsilon = 0.0853
#
# Episode 492/1000: Total reward = 601
# Episode 492/1000: Epsilon = 0.0849
#
# Episode 493/1000: Total reward = -51
# Episode 493/1000: Epsilon = 0.0845
#
# Episode 494/1000: Total reward = 1174
# Episode 494/1000: Epsilon = 0.0841
#
# Episode 495/1000: Total reward = 680
# Episode 495/1000: Epsilon = 0.0836
#
# Episode 496/1000: Total reward = 686
# Episode 496/1000: Epsilon = 0.0832
#
# Episode 497/1000: Total reward = 4492
# Episode 497/1000: Epsilon = 0.0828
#
# Episode 498/1000: Total reward = 100
# Episode 498/1000: Epsilon = 0.0824
#
# Episode 499/1000: Total reward = -51
# Episode 499/1000: Epsilon = 0.0820
#
# Episode 500/1000: Total reward = 870
# Episode 500/1000: Epsilon = 0.0816
#
# Episode 501/1000: Total reward = 2979
# Episode 501/1000: Epsilon = 0.0812
#
# Episode 502/1000: Total reward = 1227
# Episode 502/1000: Epsilon = 0.0808
#
# Episode 503/1000: Total reward = -51
# Episode 503/1000: Epsilon = 0.0804
#
# Episode 504/1000: Total reward = 1311
# Episode 504/1000: Epsilon = 0.0800
#
# Episode 505/1000: Total reward = -8
# Episode 505/1000: Epsilon = 0.0796
#
# Episode 506/1000: Total reward = -51
# Episode 506/1000: Epsilon = 0.0792
#
# Episode 507/1000: Total reward = 386
# Episode 507/1000: Epsilon = 0.0788
#
# Episode 508/1000: Total reward = -51
# Episode 508/1000: Epsilon = 0.0784
#
# Episode 509/1000: Total reward = 2252
# Episode 509/1000: Epsilon = 0.0780
#
# Episode 510/1000: Total reward = 341
# Episode 510/1000: Epsilon = 0.0776
#
# Episode 511/1000: Total reward = -10
# Episode 511/1000: Epsilon = 0.0772
#
# Episode 512/1000: Total reward = 3127
# Episode 512/1000: Epsilon = 0.0768
#
# Episode 513/1000: Total reward = -51
# Episode 513/1000: Epsilon = 0.0764
#
# Episode 514/1000: Total reward = 731
# Episode 514/1000: Epsilon = 0.0760
#
# Episode 515/1000: Total reward = 3034
# Episode 515/1000: Epsilon = 0.0757
#
# Episode 516/1000: Total reward = -51
# Episode 516/1000: Epsilon = 0.0753
#
# Episode 517/1000: Total reward = -100
# Episode 517/1000: Epsilon = 0.0749
#
# Episode 518/1000: Total reward = -51
# Episode 518/1000: Epsilon = 0.0745
#
# Episode 519/1000: Total reward = 294
# Episode 519/1000: Epsilon = 0.0742
#
# Episode 520/1000: Total reward = 2985
# Episode 520/1000: Epsilon = 0.0738
#
# Episode 521/1000: Total reward = 588
# Episode 521/1000: Epsilon = 0.0734
#
# Episode 522/1000: Total reward = -100
# Episode 522/1000: Epsilon = 0.0731
#
# Episode 523/1000: Total reward = 578
# Episode 523/1000: Epsilon = 0.0727
#
# Episode 524/1000: Total reward = -51
# Episode 524/1000: Epsilon = 0.0723
#
# Episode 525/1000: Total reward = -53
# Episode 525/1000: Epsilon = 0.0720
#
# Episode 526/1000: Total reward = -51
# Episode 526/1000: Epsilon = 0.0716
#
# Episode 527/1000: Total reward = 4696
# Episode 527/1000: Epsilon = 0.0712
#
# Episode 528/1000: Total reward = -51
# Episode 528/1000: Epsilon = 0.0709
#
# Episode 529/1000: Total reward = -51
# Episode 529/1000: Epsilon = 0.0705
#
# Episode 530/1000: Total reward = 3657
# Episode 530/1000: Epsilon = 0.0702
#
# Episode 531/1000: Total reward = 3020
# Episode 531/1000: Epsilon = 0.0698
#
# Episode 532/1000: Total reward = 1219
# Episode 532/1000: Epsilon = 0.0695
#
# Episode 533/1000: Total reward = 970
# Episode 533/1000: Epsilon = 0.0691
#
# Episode 534/1000: Total reward = 3757
# Episode 534/1000: Epsilon = 0.0688
#
# Episode 535/1000: Total reward = -100
# Episode 535/1000: Epsilon = 0.0684
#
# Episode 536/1000: Total reward = 2471
# Episode 536/1000: Epsilon = 0.0681
#
# Episode 537/1000: Total reward = 4543
# Episode 537/1000: Epsilon = 0.0678
#
# Episode 538/1000: Total reward = 970
# Episode 538/1000: Epsilon = 0.0674
#
# Episode 539/1000: Total reward = -51
# Episode 539/1000: Epsilon = 0.0671
#
# Episode 540/1000: Total reward = 484
# Episode 540/1000: Epsilon = 0.0668
#
# Episode 541/1000: Total reward = -51
# Episode 541/1000: Epsilon = 0.0664
#
# Episode 542/1000: Total reward = 0
# Episode 542/1000: Epsilon = 0.0661
#
# Episode 543/1000: Total reward = 4543
# Episode 543/1000: Epsilon = 0.0658
#
# Episode 544/1000: Total reward = -51
# Episode 544/1000: Epsilon = 0.0654
#
# Episode 545/1000: Total reward = 4747
# Episode 545/1000: Epsilon = 0.0651
#
# Episode 546/1000: Total reward = -51
# Episode 546/1000: Epsilon = 0.0648
#
# Episode 547/1000: Total reward = -51
# Episode 547/1000: Epsilon = 0.0645
#
# Episode 548/1000: Total reward = 2252
# Episode 548/1000: Epsilon = 0.0641
#
# Episode 549/1000: Total reward = 1803
# Episode 549/1000: Epsilon = 0.0638
#
# Episode 550/1000: Total reward = 4594
# Episode 550/1000: Epsilon = 0.0635
#
# Episode 551/1000: Total reward = 1509
# Episode 551/1000: Epsilon = 0.0632
#
# Episode 552/1000: Total reward = 778
# Episode 552/1000: Epsilon = 0.0629
#
# Episode 553/1000: Total reward = 4798
# Episode 553/1000: Epsilon = 0.0625
#
# Episode 554/1000: Total reward = -51
# Episode 554/1000: Epsilon = 0.0622
#
# Episode 555/1000: Total reward = 1023
# Episode 555/1000: Epsilon = 0.0619
#
# Episode 556/1000: Total reward = 1360
# Episode 556/1000: Epsilon = 0.0616
#
# Episode 557/1000: Total reward = 2911
# Episode 557/1000: Epsilon = 0.0613
#
# Episode 558/1000: Total reward = 586
# Episode 558/1000: Epsilon = 0.0610
#
# Episode 559/1000: Total reward = 1696
# Episode 559/1000: Epsilon = 0.0607
#
# Episode 560/1000: Total reward = 4492
# Episode 560/1000: Epsilon = 0.0604
#
# Episode 561/1000: Total reward = 192
# Episode 561/1000: Epsilon = 0.0601
#
# Episode 562/1000: Total reward = 1415
# Episode 562/1000: Epsilon = 0.0598
#
# Episode 563/1000: Total reward = -51
# Episode 563/1000: Epsilon = 0.0595
#
# Episode 564/1000: Total reward = 96
# Episode 564/1000: Epsilon = 0.0592
#
# Episode 565/1000: Total reward = 4441
# Episode 565/1000: Epsilon = 0.0589
#
# Episode 566/1000: Total reward = 1439
# Episode 566/1000: Epsilon = 0.0586
#
# Episode 567/1000: Total reward = 96
# Episode 567/1000: Epsilon = 0.0583
#
# Episode 568/1000: Total reward = 880
# Episode 568/1000: Epsilon = 0.0580
#
# Episode 569/1000: Total reward = -51
# Episode 569/1000: Epsilon = 0.0577
#
# Episode 570/1000: Total reward = -12
# Episode 570/1000: Epsilon = 0.0574
#
# Episode 571/1000: Total reward = 537
# Episode 571/1000: Epsilon = 0.0571
#
# Episode 572/1000: Total reward = -8
# Episode 572/1000: Epsilon = 0.0569
#
# Episode 573/1000: Total reward = -59
# Episode 573/1000: Epsilon = 0.0566
#
# Episode 574/1000: Total reward = 47
# Episode 574/1000: Epsilon = 0.0563
#
# Episode 575/1000: Total reward = 3520
# Episode 575/1000: Epsilon = 0.0560
#
# Episode 576/1000: Total reward = -51
# Episode 576/1000: Epsilon = 0.0557
#
# Episode 577/1000: Total reward = -100
# Episode 577/1000: Epsilon = 0.0555
#
# Episode 578/1000: Total reward = 4390
# Episode 578/1000: Epsilon = 0.0552
#
# Episode 579/1000: Total reward = 380
# Episode 579/1000: Epsilon = 0.0549
#
# Episode 580/1000: Total reward = -115
# Episode 580/1000: Epsilon = 0.0546
#
# Episode 581/1000: Total reward = 4747
# Episode 581/1000: Epsilon = 0.0544
#
# Episode 582/1000: Total reward = 3471
# Episode 582/1000: Epsilon = 0.0541
#
# Episode 583/1000: Total reward = -51
# Episode 583/1000: Epsilon = 0.0538
#
# Episode 584/1000: Total reward = 725
# Episode 584/1000: Epsilon = 0.0535
#
# Episode 585/1000: Total reward = -6
# Episode 585/1000: Epsilon = 0.0533
#
# Episode 586/1000: Total reward = 1952
# Episode 586/1000: Epsilon = 0.0530
#
# Episode 587/1000: Total reward = -51
# Episode 587/1000: Epsilon = 0.0527
#
# Episode 588/1000: Total reward = 541
# Episode 588/1000: Epsilon = 0.0525
#
# Episode 589/1000: Total reward = -51
# Episode 589/1000: Epsilon = 0.0522
#
# Episode 590/1000: Total reward = 1172
# Episode 590/1000: Epsilon = 0.0520
#
# Episode 591/1000: Total reward = 100
# Episode 591/1000: Epsilon = 0.0517
#
# Episode 592/1000: Total reward = 629
# Episode 592/1000: Epsilon = 0.0514
#
# Episode 593/1000: Total reward = -51
# Episode 593/1000: Epsilon = 0.0512
#
# Episode 594/1000: Total reward = 629
# Episode 594/1000: Epsilon = 0.0509
#
# Episode 595/1000: Total reward = 2936
# Episode 595/1000: Epsilon = 0.0507
#
# Episode 596/1000: Total reward = -51
# Episode 596/1000: Epsilon = 0.0504
#
# Episode 597/1000: Total reward = 4798
# Episode 597/1000: Epsilon = 0.0502
#
# Episode 598/1000: Total reward = -51
# Episode 598/1000: Epsilon = 0.0499
#
# Episode 599/1000: Total reward = 3465
# Episode 599/1000: Epsilon = 0.0497
#
# Episode 600/1000: Total reward = 237
# Episode 600/1000: Epsilon = 0.0494
#
# Episode 601/1000: Total reward = 684
# Episode 601/1000: Epsilon = 0.0492
#
# Episode 602/1000: Total reward = -51
# Episode 602/1000: Epsilon = 0.0489
#
# Episode 603/1000: Total reward = 876
# Episode 603/1000: Epsilon = 0.0487
#
# Episode 604/1000: Total reward = 970
# Episode 604/1000: Epsilon = 0.0484
#
# Episode 605/1000: Total reward = 4900
# Episode 605/1000: Epsilon = 0.0482
#
# Episode 606/1000: Total reward = 4398
# Episode 606/1000: Epsilon = 0.0479
#
# Episode 607/1000: Total reward = 4114
# Episode 607/1000: Epsilon = 0.0477
#
# Episode 608/1000: Total reward = 4239
# Episode 608/1000: Epsilon = 0.0475
#
# Episode 609/1000: Total reward = 1021
# Episode 609/1000: Epsilon = 0.0472
#
# Episode 610/1000: Total reward = 4594
# Episode 610/1000: Epsilon = 0.0470
#
# Episode 611/1000: Total reward = 384
# Episode 611/1000: Epsilon = 0.0468
#
# Episode 612/1000: Total reward = 88
# Episode 612/1000: Epsilon = 0.0465
#
# Episode 613/1000: Total reward = 0
# Episode 613/1000: Epsilon = 0.0463
#
# Episode 614/1000: Total reward = -51
# Episode 614/1000: Epsilon = 0.0461
#
# Episode 615/1000: Total reward = 586
# Episode 615/1000: Epsilon = 0.0458
#
# Episode 616/1000: Total reward = 872
# Episode 616/1000: Epsilon = 0.0456
#
# Episode 617/1000: Total reward = -51
# Episode 617/1000: Epsilon = 0.0454
#
# Episode 618/1000: Total reward = 831
# Episode 618/1000: Epsilon = 0.0452
#
# Episode 619/1000: Total reward = 0
# Episode 619/1000: Epsilon = 0.0449
#
# Episode 620/1000: Total reward = 4237
# Episode 620/1000: Epsilon = 0.0447
#
# Episode 621/1000: Total reward = 4747
# Episode 621/1000: Epsilon = 0.0445
#
# Episode 622/1000: Total reward = 4255
# Episode 622/1000: Epsilon = 0.0443
#
# Episode 623/1000: Total reward = 245
# Episode 623/1000: Epsilon = 0.0440
#
# Episode 624/1000: Total reward = 337
# Episode 624/1000: Epsilon = 0.0438
#
# Episode 625/1000: Total reward = 4696
# Episode 625/1000: Epsilon = 0.0436
#
# Episode 626/1000: Total reward = 3616
# Episode 626/1000: Epsilon = 0.0434
#
# Episode 627/1000: Total reward = 3810
# Episode 627/1000: Epsilon = 0.0432
#
# Episode 628/1000: Total reward = -51
# Episode 628/1000: Epsilon = 0.0429
#
# Episode 629/1000: Total reward = 2495
# Episode 629/1000: Epsilon = 0.0427
#
# Episode 630/1000: Total reward = 4747
# Episode 630/1000: Epsilon = 0.0425
#
# Episode 631/1000: Total reward = 874
# Episode 631/1000: Epsilon = 0.0423
#
# Episode 632/1000: Total reward = 635
# Episode 632/1000: Epsilon = 0.0421
#
# Episode 633/1000: Total reward = -100
# Episode 633/1000: Epsilon = 0.0419
#
# Episode 634/1000: Total reward = 831
# Episode 634/1000: Epsilon = 0.0417
#
# Episode 635/1000: Total reward = 3714
# Episode 635/1000: Epsilon = 0.0415
#
# Episode 636/1000: Total reward = 629
# Episode 636/1000: Epsilon = 0.0413
#
# Episode 637/1000: Total reward = -51
# Episode 637/1000: Epsilon = 0.0410
#
# Episode 638/1000: Total reward = 4696
# Episode 638/1000: Epsilon = 0.0408
#
# Episode 639/1000: Total reward = -51
# Episode 639/1000: Epsilon = 0.0406
#
# Episode 640/1000: Total reward = 1070
# Episode 640/1000: Epsilon = 0.0404
#
# Episode 641/1000: Total reward = 1372
# Episode 641/1000: Epsilon = 0.0402
#
# Episode 642/1000: Total reward = -51
# Episode 642/1000: Epsilon = 0.0400
#
# Episode 643/1000: Total reward = 4900
# Episode 643/1000: Epsilon = 0.0398
#
# Episode 644/1000: Total reward = 4645
# Episode 644/1000: Epsilon = 0.0396
#
# Episode 645/1000: Total reward = 4543
# Episode 645/1000: Epsilon = 0.0394
#
# Episode 646/1000: Total reward = 4594
# Episode 646/1000: Epsilon = 0.0392
#
# Episode 647/1000: Total reward = 1125
# Episode 647/1000: Epsilon = 0.0390
#
# Episode 648/1000: Total reward = 2150
# Episode 648/1000: Epsilon = 0.0388
#
# Episode 649/1000: Total reward = -51
# Episode 649/1000: Epsilon = 0.0387
#
# Episode 650/1000: Total reward = -51
# Episode 650/1000: Epsilon = 0.0385
#
# Episode 651/1000: Total reward = 1421
# Episode 651/1000: Epsilon = 0.0383
#
# Episode 652/1000: Total reward = -51
# Episode 652/1000: Epsilon = 0.0381
#
# Episode 653/1000: Total reward = 552
# Episode 653/1000: Epsilon = 0.0379
#
# Episode 654/1000: Total reward = 0
# Episode 654/1000: Epsilon = 0.0377
#
# Episode 655/1000: Total reward = 0
# ...
#
# Episode 783/1000: Total reward = 4645
# Episode 783/1000: Epsilon = 0.0197
#
# Episode 784/1000: Total reward = 4600
# Episode 784/1000: Epsilon = 0.0196
#
# Episode 785/1000: Total reward = 4849
# Episode 785/1000: Epsilon = 0.0195
#
# Episode 786/1000: Total reward = 3869
# Episode 786/1000: Epsilon = 0.0195
#
# Episode 787/1000: Total reward = -51
# Episode 787/1000: Epsilon = 0.0194
#
# Episode 788/1000: Total reward = 0
# Episode 788/1000: Epsilon = 0.0193
#
# Episode 789/1000: Total reward = 4900
# Episode 789/1000: Epsilon = 0.0192
#
# Episode 790/1000: Total reward = 4849
# Episode 790/1000: Epsilon = 0.0191
#
# Episode 791/1000: Total reward = 586
# Episode 791/1000: Epsilon = 0.0190
#
# Episode 792/1000: Total reward = 4900
# Episode 792/1000: Epsilon = 0.0189
#
# Episode 793/1000: Total reward = 2689
# Episode 793/1000: Epsilon = 0.0188
#
# Episode 794/1000: Total reward = -100
# Episode 794/1000: Epsilon = 0.0187
#
# Episode 795/1000: Total reward = 2546
# Episode 795/1000: Epsilon = 0.0186
#
# Episode 796/1000: Total reward = 4696
# Episode 796/1000: Epsilon = 0.0185
#
# Episode 797/1000: Total reward = 4900
# Episode 797/1000: Epsilon = 0.0184
#
# Episode 798/1000: Total reward = 4406
# Episode 798/1000: Epsilon = 0.0183
#
# Episode 799/1000: Total reward = 4900
# Episode 799/1000: Epsilon = 0.0182
#
# Episode 800/1000: Total reward = 4747
# Episode 800/1000: Epsilon = 0.0181
#
# Episode 801/1000: Total reward = 0
# Episode 801/1000: Epsilon = 0.0180
#
# Episode 802/1000: Total reward = 1321
# Episode 802/1000: Epsilon = 0.0180
#
# Episode 803/1000: Total reward = 4849
# Episode 803/1000: Epsilon = 0.0179
#
# Episode 804/1000: Total reward = 0
# Episode 804/1000: Epsilon = 0.0178
#
# Episode 805/1000: Total reward = 1270
# Episode 805/1000: Epsilon = 0.0177
#
# Episode 806/1000: Total reward = 3767
# Episode 806/1000: Epsilon = 0.0176
#
# Episode 807/1000: Total reward = -51
# Episode 807/1000: Epsilon = 0.0175
#
# Episode 808/1000: Total reward = 4849
# Episode 808/1000: Epsilon = 0.0174
#
# Episode 809/1000: Total reward = 4900
# Episode 809/1000: Epsilon = 0.0173
#
# Episode 810/1000: Total reward = 4900
# Episode 810/1000: Epsilon = 0.0172
#
# Episode 811/1000: Total reward = 4696
# Episode 811/1000: Epsilon = 0.0172
#
# Episode 812/1000: Total reward = 2693
# Episode 812/1000: Epsilon = 0.0171
#
# Episode 813/1000: Total reward = 1315
# Episode 813/1000: Epsilon = 0.0170
#
# Episode 814/1000: Total reward = -51
# Episode 814/1000: Epsilon = 0.0169
#
# Episode 815/1000: Total reward = -100
# Episode 815/1000: Epsilon = 0.0168
#
# Episode 816/1000: Total reward = 3130
# Episode 816/1000: Epsilon = 0.0167
#
# Episode 817/1000: Total reward = 4351
# Episode 817/1000: Epsilon = 0.0167
#
# Episode 818/1000: Total reward = -51
# Episode 818/1000: Epsilon = 0.0166
#
# Episode 819/1000: Total reward = 2883
# Episode 819/1000: Epsilon = 0.0165
#
# Episode 820/1000: Total reward = 100
# Episode 820/1000: Epsilon = 0.0164
#
# Episode 821/1000: Total reward = 0
# Episode 821/1000: Epsilon = 0.0163
#
# Episode 822/1000: Total reward = -51
# Episode 822/1000: Epsilon = 0.0162
#
# Episode 823/1000: Total reward = -51
# Episode 823/1000: Epsilon = 0.0162
#
# Episode 824/1000: Total reward = 235
# Episode 824/1000: Epsilon = 0.0161
#
# Episode 825/1000: Total reward = -100
# Episode 825/1000: Epsilon = 0.0160
#
# Episode 826/1000: Total reward = -51
# Episode 826/1000: Epsilon = 0.0159
#
# Episode 827/1000: Total reward = 4033
# Episode 827/1000: Epsilon = 0.0158
#
# Episode 828/1000: Total reward = 4747
# Episode 828/1000: Epsilon = 0.0158
#
# Episode 829/1000: Total reward = 1132
# Episode 829/1000: Epsilon = 0.0157
#
# Episode 830/1000: Total reward = 4747
# Episode 830/1000: Epsilon = 0.0156
#
# Episode 831/1000: Total reward = 4696
# Episode 831/1000: Epsilon = 0.0155
#
# Episode 832/1000: Total reward = -51
# Episode 832/1000: Epsilon = 0.0154
#
# Episode 833/1000: Total reward = -51
# Episode 833/1000: Epsilon = 0.0154
#
# Episode 834/1000: Total reward = 978
# Episode 834/1000: Epsilon = 0.0153
#
# Episode 835/1000: Total reward = 3013
# Episode 835/1000: Epsilon = 0.0152
#
# Episode 836/1000: Total reward = -51
# Episode 836/1000: Epsilon = 0.0151
#
# Episode 837/1000: Total reward = -51
# Episode 837/1000: Epsilon = 0.0151
#
# Episode 838/1000: Total reward = 1331
# Episode 838/1000: Epsilon = 0.0150
#
# Episode 839/1000: Total reward = 4645
# Episode 839/1000: Epsilon = 0.0149
#
# Episode 840/1000: Total reward = 2197
# Episode 840/1000: Epsilon = 0.0148
#
# Episode 841/1000: Total reward = 4798
# Episode 841/1000: Epsilon = 0.0148
#
# Episode 842/1000: Total reward = -51
# Episode 842/1000: Epsilon = 0.0147
#
# Episode 843/1000: Total reward = -51
# Episode 843/1000: Epsilon = 0.0146
#
# Episode 844/1000: Total reward = -51
# Episode 844/1000: Epsilon = 0.0145
#
# Episode 845/1000: Total reward = -51
# Episode 845/1000: Epsilon = 0.0145
#
# Episode 846/1000: Total reward = 4596
# Episode 846/1000: Epsilon = 0.0144
#
# Episode 847/1000: Total reward = -51
# Episode 847/1000: Epsilon = 0.0143
#
# Episode 848/1000: Total reward = -51
# Episode 848/1000: Epsilon = 0.0143
#
# Episode 849/1000: Total reward = -51
# Episode 849/1000: Epsilon = 0.0142
#
# Episode 850/1000: Total reward = 2105
# Episode 850/1000: Epsilon = 0.0141
#
# Episode 851/1000: Total reward = 4900
# Episode 851/1000: Epsilon = 0.0140
#
# Episode 852/1000: Total reward = 4645
# Episode 852/1000: Epsilon = 0.0140
#
# Episode 853/1000: Total reward = 4747
# Episode 853/1000: Epsilon = 0.0139
#
# Episode 854/1000: Total reward = 4543
# Episode 854/1000: Epsilon = 0.0138
#
# Episode 855/1000: Total reward = 4900
# Episode 855/1000: Epsilon = 0.0138
#
# Episode 856/1000: Total reward = 100
# Episode 856/1000: Epsilon = 0.0137
#
# Episode 857/1000: Total reward = -51
# Episode 857/1000: Epsilon = 0.0136
#
# Episode 858/1000: Total reward = 4849
# Episode 858/1000: Epsilon = 0.0136
#
# Episode 859/1000: Total reward = 4747
# Episode 859/1000: Epsilon = 0.0135
#
# Episode 860/1000: Total reward = 782
# Episode 860/1000: Epsilon = 0.0134
#
# Episode 861/1000: Total reward = 4441
# Episode 861/1000: Epsilon = 0.0134
#
# Episode 862/1000: Total reward = -200
# Episode 862/1000: Epsilon = 0.0133
#
# Episode 863/1000: Total reward = 4645
# Episode 863/1000: Epsilon = 0.0132
#
# Episode 864/1000: Total reward = 4747
# Episode 864/1000: Epsilon = 0.0132
#
# Episode 865/1000: Total reward = -51
# Episode 865/1000: Epsilon = 0.0131
#
# Episode 866/1000: Total reward = 2785
# Episode 866/1000: Epsilon = 0.0130
#
# Episode 867/1000: Total reward = 2838
# Episode 867/1000: Epsilon = 0.0130
#
# Episode 868/1000: Total reward = 4798
# Episode 868/1000: Epsilon = 0.0129
#
# Episode 869/1000: Total reward = 0
# Episode 869/1000: Epsilon = 0.0128
#
# Episode 870/1000: Total reward = -51
# Episode 870/1000: Epsilon = 0.0128
#
# Episode 871/1000: Total reward = 4747
# Episode 871/1000: Epsilon = 0.0127
#
# Episode 872/1000: Total reward = 4747
# Episode 872/1000: Epsilon = 0.0126
#
# Episode 873/1000: Total reward = 4900
# Episode 873/1000: Epsilon = 0.0126
#
# Episode 874/1000: Total reward = 4798
# Episode 874/1000: Epsilon = 0.0125
#
# Episode 875/1000: Total reward = 1856
# Episode 875/1000: Epsilon = 0.0125
#
# Episode 876/1000: Total reward = -51
# Episode 876/1000: Epsilon = 0.0124
#
# Episode 877/1000: Total reward = 4900
# Episode 877/1000: Epsilon = 0.0123
#
# Episode 878/1000: Total reward = -51
# Episode 878/1000: Epsilon = 0.0123
#
# Episode 879/1000: Total reward = 4900
# Episode 879/1000: Epsilon = 0.0122
#
# Episode 880/1000: Total reward = 4900
# Episode 880/1000: Epsilon = 0.0121
#
# Episode 881/1000: Total reward = 4900
# Episode 881/1000: Epsilon = 0.0121
#
# Episode 882/1000: Total reward = 3232
# Episode 882/1000: Epsilon = 0.0120
#
# Episode 883/1000: Total reward = 678
# Episode 883/1000: Epsilon = 0.0120
#
# Episode 884/1000: Total reward = 1809
# Episode 884/1000: Epsilon = 0.0119
#
# Episode 885/1000: Total reward = 4747
# Episode 885/1000: Epsilon = 0.0118
#
# Episode 886/1000: Total reward = 4849
# Episode 886/1000: Epsilon = 0.0118
#
# Episode 887/1000: Total reward = 4696
# Episode 887/1000: Epsilon = 0.0117
#
# Episode 888/1000: Total reward = 1174
# Episode 888/1000: Epsilon = 0.0117
#
# Episode 889/1000: Total reward = 4900
# Episode 889/1000: Epsilon = 0.0116
#
# Episode 890/1000: Total reward = 4747
# Episode 890/1000: Epsilon = 0.0115
#
# Episode 891/1000: Total reward = 3471
# Episode 891/1000: Epsilon = 0.0115
#
# Episode 892/1000: Total reward = -51
# Episode 892/1000: Epsilon = 0.0114
#
# Episode 893/1000: Total reward = 4849
# Episode 893/1000: Epsilon = 0.0114
#
# Episode 894/1000: Total reward = -51
# Episode 894/1000: Epsilon = 0.0113
#
# Episode 895/1000: Total reward = 1413
# Episode 895/1000: Epsilon = 0.0113
#
# Episode 896/1000: Total reward = -51
# Episode 896/1000: Epsilon = 0.0112
#
# Episode 897/1000: Total reward = 4849
# Episode 897/1000: Epsilon = 0.0112
#
# Episode 898/1000: Total reward = 4747
# Episode 898/1000: Epsilon = 0.0111
#
# Episode 899/1000: Total reward = 4900
# Episode 899/1000: Epsilon = 0.0110
#
# Episode 900/1000: Total reward = 4849
# Episode 900/1000: Epsilon = 0.0110
#
# Episode 901/1000: Total reward = 3472
# Episode 901/1000: Epsilon = 0.0109
#
# Episode 902/1000: Total reward = 4747
# Episode 902/1000: Epsilon = 0.0109
#
# Episode 903/1000: Total reward = -100
# Episode 903/1000: Epsilon = 0.0108
#
# Episode 904/1000: Total reward = 1313
# Episode 904/1000: Epsilon = 0.0108
#
# Episode 905/1000: Total reward = 4849
# Episode 905/1000: Epsilon = 0.0107
#
# Episode 906/1000: Total reward = -51
# Episode 906/1000: Epsilon = 0.0107
#
# Episode 907/1000: Total reward = 2936
# Episode 907/1000: Epsilon = 0.0106
#
# Episode 908/1000: Total reward = 4849
# Episode 908/1000: Epsilon = 0.0106
#
# Episode 909/1000: Total reward = 4849
# Episode 909/1000: Epsilon = 0.0105
#
# Episode 910/1000: Total reward = -100
# Episode 910/1000: Epsilon = 0.0104
#
# Episode 911/1000: Total reward = 4849
# Episode 911/1000: Epsilon = 0.0104
#
# Episode 912/1000: Total reward = 4900
# Episode 912/1000: Epsilon = 0.0103
#
# Episode 913/1000: Total reward = 4747
# Episode 913/1000: Epsilon = 0.0103
#
# Episode 914/1000: Total reward = 100
# Episode 914/1000: Epsilon = 0.0102
#
# Episode 915/1000: Total reward = 4594
# Episode 915/1000: Epsilon = 0.0102
#
# Episode 916/1000: Total reward = 4747
# Episode 916/1000: Epsilon = 0.0101
#
# Episode 917/1000: Total reward = 4645
# Episode 917/1000: Epsilon = 0.0101
#
# Episode 918/1000: Total reward = 4747
# Episode 918/1000: Epsilon = 0.0100
#
# Episode 919/1000: Total reward = 4849
# Episode 919/1000: Epsilon = 0.0100
#
# Episode 920/1000: Total reward = 4186
# Episode 920/1000: Epsilon = 0.0100
#
# Episode 921/1000: Total reward = 1566
# Episode 921/1000: Epsilon = 0.0100
#
# Episode 922/1000: Total reward = 4747
# Episode 922/1000: Epsilon = 0.0100
#
# Episode 923/1000: Total reward = 4594
# Episode 923/1000: Epsilon = 0.0100
#
# Episode 924/1000: Total reward = 4747
# Episode 924/1000: Epsilon = 0.0100
#
# Episode 925/1000: Total reward = 4849
# Episode 925/1000: Epsilon = 0.0100
#
# Episode 926/1000: Total reward = 4900
# Episode 926/1000: Epsilon = 0.0100
#
# Episode 927/1000: Total reward = 4798
# Episode 927/1000: Epsilon = 0.0100
#
# Episode 928/1000: Total reward = 4900
# Episode 928/1000: Epsilon = 0.0100
#
# Episode 929/1000: Total reward = 1360
# Episode 929/1000: Epsilon = 0.0100
#
# Episode 930/1000: Total reward = 2448
# Episode 930/1000: Epsilon = 0.0100
#
# Episode 931/1000: Total reward = 4257
# Episode 931/1000: Epsilon = 0.0100
#
# Episode 932/1000: Total reward = -100
# Episode 932/1000: Epsilon = 0.0100
#
# Episode 933/1000: Total reward = 4849
# Episode 933/1000: Epsilon = 0.0100
#
# Episode 934/1000: Total reward = -51
# Episode 934/1000: Epsilon = 0.0100
#
# Episode 935/1000: Total reward = -51
# Episode 935/1000: Epsilon = 0.0100
#
# Episode 936/1000: Total reward = 4798
# Episode 936/1000: Epsilon = 0.0100
#
# Episode 937/1000: Total reward = 4849
# Episode 937/1000: Epsilon = 0.0100
#
# Episode 938/1000: Total reward = -51
# Episode 938/1000: Epsilon = 0.0100
#
# Episode 939/1000: Total reward = -51
# Episode 939/1000: Epsilon = 0.0100
#
# Episode 940/1000: Total reward = 4900
# Episode 940/1000: Epsilon = 0.0100
#
# Episode 941/1000: Total reward = 337
# Episode 941/1000: Epsilon = 0.0100
#
# Episode 942/1000: Total reward = -51
# Episode 942/1000: Epsilon = 0.0100
#
# Episode 943/1000: Total reward = -100
# Episode 943/1000: Epsilon = 0.0100
#
# Episode 944/1000: Total reward = 4441
# Episode 944/1000: Epsilon = 0.0100
#
# Episode 945/1000: Total reward = 4108
# Episode 945/1000: Epsilon = 0.0100
#
# Episode 946/1000: Total reward = 4900
# Episode 946/1000: Epsilon = 0.0100
#
# Episode 947/1000: Total reward = 4645
# Episode 947/1000: Epsilon = 0.0100
#
# Episode 948/1000: Total reward = 4696
# Episode 948/1000: Epsilon = 0.0100
#
# Episode 949/1000: Total reward = 1068
# Episode 949/1000: Epsilon = 0.0100
#
# Episode 950/1000: Total reward = 100
# Episode 950/1000: Epsilon = 0.0100
#
# Episode 951/1000: Total reward = 4696
# Episode 951/1000: Epsilon = 0.0100
#
# Episode 952/1000: Total reward = 4900
# Episode 952/1000: Epsilon = 0.0100
#
# Episode 953/1000: Total reward = 1513
# Episode 953/1000: Epsilon = 0.0100
#
# Episode 954/1000: Total reward = 3816
# Episode 954/1000: Epsilon = 0.0100
#
# Episode 955/1000: Total reward = 1178
# Episode 955/1000: Epsilon = 0.0100
#
# Episode 956/1000: Total reward = 3778
# Episode 956/1000: Epsilon = 0.0100
#
# Episode 957/1000: Total reward = 4900
# Episode 957/1000: Epsilon = 0.0100
#
# Episode 958/1000: Total reward = 0
# Episode 958/1000: Epsilon = 0.0100
#
# Episode 959/1000: Total reward = 0
# Episode 959/1000: Epsilon = 0.0100
#
# Episode 960/1000: Total reward = -51
# Episode 960/1000: Epsilon = 0.0100
#
# Episode 961/1000: Total reward = 4747
# Episode 961/1000: Epsilon = 0.0100
#
# Episode 962/1000: Total reward = -51
# Episode 962/1000: Epsilon = 0.0100
#
# Episode 963/1000: Total reward = 0
# Episode 963/1000: Epsilon = 0.0100
#
# Episode 964/1000: Total reward = -51
# Episode 964/1000: Epsilon = 0.0100
#
# Episode 965/1000: Total reward = 4390
# Episode 965/1000: Epsilon = 0.0100
#
# Episode 966/1000: Total reward = 4900
# Episode 966/1000: Epsilon = 0.0100
#
# Episode 967/1000: Total reward = 4849
# Episode 967/1000: Epsilon = 0.0100
#
# Episode 968/1000: Total reward = 4696
# Episode 968/1000: Epsilon = 0.0100
#
# Episode 969/1000: Total reward = 3575
# Episode 969/1000: Epsilon = 0.0100
#
# Episode 970/1000: Total reward = 4594
# Episode 970/1000: Epsilon = 0.0100
#
# Episode 971/1000: Total reward = 4798
# Episode 971/1000: Epsilon = 0.0100
#
# Episode 972/1000: Total reward = 3863
# Episode 972/1000: Epsilon = 0.0100
#
# Episode 973/1000: Total reward = -51
# Episode 973/1000: Epsilon = 0.0100
#
# Episode 974/1000: Total reward = 2642
# Episode 974/1000: Epsilon = 0.0100
#
# Episode 975/1000: Total reward = 4849
# Episode 975/1000: Epsilon = 0.0100
#
# Episode 976/1000: Total reward = -51
# Episode 976/1000: Epsilon = 0.0100
#
# Episode 977/1000: Total reward = 4208
# Episode 977/1000: Epsilon = 0.0100
#
# Episode 978/1000: Total reward = 92
# Episode 978/1000: Epsilon = 0.0100
#
# Episode 979/1000: Total reward = 4594
# Episode 979/1000: Epsilon = 0.0100
#
# Episode 980/1000: Total reward = 4849
# Episode 980/1000: Epsilon = 0.0100
#
# Episode 981/1000: Total reward = 4849
# Episode 981/1000: Epsilon = 0.0100
#
# Episode 982/1000: Total reward = -51
# Episode 982/1000: Epsilon = 0.0100
#
# Episode 983/1000: Total reward = 4645
# Episode 983/1000: Epsilon = 0.0100
#
# Episode 984/1000: Total reward = 3861
# Episode 984/1000: Epsilon = 0.0100
#
# Episode 985/1000: Total reward = 4645
# Episode 985/1000: Epsilon = 0.0100
#
# Episode 986/1000: Total reward = 4798
# Episode 986/1000: Epsilon = 0.0100
#
# Episode 987/1000: Total reward = 4798
# Episode 987/1000: Epsilon = 0.0100
#
# Episode 988/1000: Total reward = 676
# Episode 988/1000: Epsilon = 0.0100
#
# Episode 989/1000: Total reward = 4900
# Episode 989/1000: Epsilon = 0.0100
#
# Episode 990/1000: Total reward = 4645
# Episode 990/1000: Epsilon = 0.0100
#
# Episode 991/1000: Total reward = 0
# Episode 991/1000: Epsilon = 0.0100
#
# Episode 992/1000: Total reward = 4747
# Episode 992/1000: Epsilon = 0.0100
#
# Episode 993/1000: Total reward = 4747
# Episode 993/1000: Epsilon = 0.0100
#
# Episode 994/1000: Total reward = 4900
# Episode 994/1000: Epsilon = 0.0100
#
# Episode 995/1000: Total reward = 4747
# Episode 995/1000: Epsilon = 0.0100
#
# Episode 996/1000: Total reward = 4900
# Episode 996/1000: Epsilon = 0.0100
#
# Episode 997/1000: Total reward = 186
# Episode 997/1000: Epsilon = 0.0100
#
# Episode 998/1000: Total reward = 3561
# Episode 998/1000: Epsilon = 0.0100
#
# Episode 999/1000: Total reward = 4798
# Episode 999/1000: Epsilon = 0.0100

# %%
# LIBRARY TO CREATE GRAPHICS
import matplotlib.pyplot as plt

# GRAPH FOR ACCUMULATED REWARD PER EPISODE
plt.figure(figsize=(12,7))
plt.plot(rewards_per_episode, label='LEARNING PERFORMANCE')
plt.xlabel('Episodes')
plt.ylabel('Accumulated reward')
plt.title('Accumulated rewards per episode')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# **DRL** agent evaluation.
#
# ---

# %%
# TEST PARAMETERS
test_episodes = 200
test_rewards = []
cpu_usage_final_per_test_episode = []
ram_usage_final_per_test_episode = []
# TEST PREDICT LOOP
for e in range(test_episodes):
  # RESET PARAMETERS PER EPISODE
  state = env.reset()
  state = np.reshape(state, [1, state_size])
  total_reward = 0
  done = False
  # FINALIZATION EPISODE LOOP
  while not done:
    # SELECT ACTION
    action = np.argmax(agent.model.predict(state, verbose=0))
    # EXECUTE ACTION
    next_state, reward, done, _ = env.step(action)
    # SAVE REWARD
    total_reward += reward
    # UPDATE CURRENT STATE
    state = np.reshape(next_state, [1, state_size])
  # SAVE REWARDS PER EPISODE
  test_rewards.append(total_reward)
  cpu_usage_final_per_test_episode.append(env.num_CPU)
  ram_usage_final_per_test_episode.append(env.num_RAM)
# OBTAIN THE AVERAGE TEST REWARD
avg_test_reward = np.mean(test_rewards)
print(f'Average reward in {test_episodes} test episodes: {avg_test_reward}')
# Out:
# Average reward in 200 test episodes: 3182.795

# %%
# CHART FOR CPU PERFORMANCE
plt.figure(figsize = (12,7))
plt.plot(cpu_usage_final_per_test_episode, label='CPU Usage')
plt.xlabel('Test Episodes')
plt.ylabel('CPU Cores Used')
plt.title('Final CPU Usage per Test Episode')
plt.grid(True)
plt.show()

# %%
# CHART FOR RAM PERFORMANCE
plt.figure(figsize = (12,7))
plt.plot(ram_usage_final_per_test_episode, label='RAM Usage', color='orange')
plt.xlabel('Test Episodes')
plt.ylabel('RAM (GB) Used')
plt.title('Final RAM Usage per Test Episode')
plt.grid(True)
plt.show()
